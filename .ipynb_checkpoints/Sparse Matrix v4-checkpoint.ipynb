# %%
#Packages for dataframe manipulation and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Packages for natural language processing
import nltk
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.preprocessing import Normalizer
from sklearn.decomposition import TruncatedSVD

#Updating default settings
pd.set_option('display.max_columns', 1000)

# %%
dataset = pd.read_pickle('other_xmltodict_all_major_fields.pkl')

# %%
### Drop the rows with no values in section_bodies
dataset = dataset[dataset['section_bodies'] != 'Null']
print("Without Null rows: " + str(len(dataset)))
# Out:
# Without Null rows: 2520

# %%
#only keep the SOR and CRC...SI are not included in the scope
dataset['regulation_type'].value_counts()
# Out:
# SOR     2265
# SI       246
# Null       9
# Name: regulation_type, dtype: int64

# %%
dataset = dataset[dataset['regulation_type']!= 'SI']

# %% [markdown]
# ## 1. Creating the Corpus & Sparse Matrix

# %%
def make_corpus(dataset, column):
    '''This function reads in a pandas dataframe (dataset) and the column name (e.g. 'text_column'). 
    Then it strips all punctuation, makes it lower case, tokenizes it, and removes english stopwords. 
    Finally it returns two lists (either directly or via tuple unpacking. the first is the documents
    without stopwords; the second is the documents stemmed via porterstemmer.
    '''
    from nltk.corpus import stopwords
    from nltk.tokenize import word_tokenize
    stop_words = set(stopwords.words('english'))
    import string 
    import sys
    translator = str.maketrans('', '', string.punctuation)
    import re
    from nltk.stem import PorterStemmer
    ps = PorterStemmer()
    filtered_text_list = []
    stemmed_text_list = []
    for i in range (0, len(dataset)):
        text = dataset.iloc[i][column].lower().translate(translator)
        text = re.sub('\n', ' ', text)
        word_tokens = word_tokenize(text) 
        filtered_text = [w for w in word_tokens if not w in stop_words]
        filtered_text = []
        for w in word_tokens:
            if w not in stop_words:
                filtered_text.append(w)
        stemmed_text = []
        for w in filtered_text:
            stemmed_text.append(ps.stem(w))
        filtered_text_list.append(str(filtered_text).translate(translator))
        stemmed_text_list.append(str(stemmed_text).translate(translator))
        #sys.stdout.write("\r" + "Creating Corpus.. Processing Record: " + str(i+1) + " of " + str(len(dataset)))
        #sys.stdout.flush()
    print("\nDONE!")
    return filtered_text_list, stemmed_text_list

# %%
filtered_text, stemmed_text = make_corpus(dataset,'section_bodies')
# Out:
# Creating Corpus.. Processing Record: 2274 of 2274
# DONE!

# %%
cv = CountVectorizer()
X = cv.fit_transform(stemmed_text).toarray()

# %%
X.shape
# Out:
# (2274, 12595)

# %%
df_sparse = pd.DataFrame(X, columns = cv.get_feature_names())

# %% [markdown]
# ## 2. Cleaning the Sparse Matrix

# %%
features = pd.Series(df_sparse.columns)

# %% [markdown]
# ##### Removing features which contain a number

# %%
def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString)

# %%
#remove all the features which are numeric
index = features.map(hasNumbers)

# %%
#how many are numeric?
index.value_counts()
# Out:
# False    7512
# True     5083
# dtype: int64

# %%
#list of features to drop
dropped_features = features[index]

# %%
len(dropped_features)
# Out:
# 5083

# %%
#Drop it like its hot
df_sparse = df_sparse.drop(columns=dropped_features)

# %%
df_sparse.shape
# Out:
# (2274, 7512)

# %% [markdown]
# ##### Removing the helping verbs

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()

# %%
#There are 23 helping verbs in total
helping_verbs = ['am', 'is', 'are', 'was', 'were', 'being', 'been', 'be', 'have', 'has', 'had', 'do', 'does', 
                 'did', 'will', 'would', 'shall', 'should', 'may', 'might', 'must', 'can', 'could']

#Obtain the stemed version of each word
helping_verbs_stemmed = []
for verb in helping_verbs:
    helping_verbs_stemmed.append(ps.stem(verb).lower())

# %%
#Which helping verbs are in the sparse matrix?
helping_verbs_stemmed_drop = []

cols = list(df_sparse.columns)

for verb in helping_verbs_stemmed:
    if verb in cols:
        helping_verbs_stemmed_drop.append(verb)
        
print (helping_verbs_stemmed_drop)
# Out:
# ['will', 'would', 'shall', 'may', 'might', 'must', 'could']

# %%
#Remove the helping verbs and check the outcomes
print ('shape before dropping helping verbs:' + str(df_sparse.shape))

df_sparse = df_sparse.drop(columns=helping_verbs_stemmed_drop)

print ('shape after dropping helping verbs:' + str(df_sparse.shape))
# Out:
# shape before dropping helping verbs:(2274, 7512)
# shape after dropping helping verbs:(2274, 7505)

# %% [markdown]
# ## 3. TF-IDF Vectorizer

# %%
#convert the count matrix to tf-idf representation
transformer = TfidfTransformer()
tfidf = transformer.fit_transform(df_sparse).toarray()

# %%
#df_sparse = pd.DataFrame(tfidf, columns = cols)

# %%
feature_names = df_sparse.columns

# find maximum value for each of the features over all of dataset:
max_val = df_sparse.max(axis=0).ravel()

#sort weights from smallest to biggest and extract their indices 
sort_by_tfidf = max_val.argsort()

print("Features with lowest tfidf:\n{}".format(
      feature_names[sort_by_tfidf[:20]]))

print("\nFeatures with highest tfidf: \n{}".format(
      feature_names[sort_by_tfidf[-20:]]))
# Out:
# Features with lowest tfidf:
# Index(['northwestel', 'speech', 'premiumpay', 'spednic', 'spectat',
#        'discredit', 'prepaidport', 'discriminatori', 'sphere', 'iran', 'ipc',
#        'ioniz', 'ionexchang', 'dish', 'dishonest', 'sovereignti', 'ioc',
#        'sparkler', 'discomfort', 'discolor'],
#       dtype='object')
#
# Features with highest tfidf:
# Index(['appeal', 'particular', 'system', 'categori', 'licenc', 'produc',
#        'hazard', 'act', 'particip', 'certif', 'ferri', 'store', 'vessel',
#        'subsect', 'dive', 'suppli', 'invest', 'food', 'plan', 'explos'],
#       dtype='object')

# %% [markdown]
# ## 4. Latent Semantic Analysis

# %%
lsa = TruncatedSVD(n_components = 100, algorithm='arpack', random_state=0)
dtm_lsa = lsa.fit_transform(tfidf)

# %%
#What are the top components of each concept?
for i, comp in enumerate(lsa.components_):
    terms_in_comp = zip(cols,comp)
    sorted_terms = sorted(terms_in_comp, key=lambda x: x[1], reverse=True)[:10]
    print('Concept %d:' %i)
    
    for term in sorted_terms:
        print(term[0])
    print (' ')
# Out:
# Concept 0:
# forbid
# come
# datum
# regi
# registrar
# lamproom
# optim
# nwtsoirc
# secretari
# perpendicular
#
# Concept 1:
# lamproom
# nwtsoirc
# plywood
# element
# airport
# build
# stripe
# appli
# grown
# oviduct
#
# Concept 2:
# board
# act
# perpendicular
# subrul
# marker
# commod
# author
# poult
# secretari
# purg
#
# Concept 3:
# board
# commod
# marker
# poult
# exempt
# protrud
# interpret
# tp
# optim
# exponentialtimeaverag
#
# Concept 4:
# immov
# prisonerofwar
# articl
# convent
# remarri
# canada
# ordinari
# optim
# extens
# grandpar
#
# Concept 5:
# remarri
# grandpar
# gone
# implic
# condit
# optim
# custodian
# pave
# paddleboat
# dustproof
#
# Concept 6:
# compani
# bank
# entireti
# remarri
# hoist
# grandpar
# insul
# invert
# acquir
# subsidiari
#
# Concept 7:
# gone
# station
# canada
# implic
# registrar
# chapter
# exponentialtimeaverag
# come
# forbid
# enabl
#
# Concept 8:
# permafrost
# exponentialtimeaverag
# gone
# author
# regi
# implic
# optim
# compani
# scare
# bank
#
# Concept 9:
# insul
# proclaim
# miner
# loadcarri
# lever
# applic
# board
# lend
# compani
# prioriti
#
# Concept 10:
# column
# servant
# scare
# proclaim
# lever
# italic
# amount
# paus
# font
# pave
#
# Concept 11:
# terminolog
# scare
# herbarium
# author
# norsk
# miner
# poult
# column
# employ
# interdepartment
#
# Concept 12:
# emplan
# terminolog
# proclaim
# lever
# perpendicular
# employ
# seriou
# herbarium
# acquir
# canada
#
# Concept 13:
# insul
# regi
# loadcarri
# terminolog
# lend
# amount
# datum
# gone
# prioriti
# miner
#
# Concept 14:
# station
# parliament
# chapter
# applic
# act
# healthi
# terminolog
# fiii
# judaic
# appeal
#
# Concept 15:
# compani
# optim
# gone
# emplan
# parliament
# seriou
# tankless
# healthi
# come
# forbid
#
# Concept 16:
# bank
# registrar
# forego
# entireti
# notif
# implic
# juic
# associ
# gone
# scare
#
# Concept 17:
# optim
# obliter
# radiant
# forbid
# executor
# come
# subrul
# interfac
# act
# prereconsolid
#
# Concept 18:
# bank
# emplan
# optim
# column
# seriou
# gone
# italic
# tankless
# station
# perpendicular
#
# Concept 19:
# permafrost
# exponentialtimeaverag
# emplan
# applic
# alloc
# column
# condit
# ceas
# optim
# remarri
#
# Concept 20:
# insul
# loadcarri
# lend
# prereconsolid
# bank
# prioriti
# emplan
# influenza
# board
# purg
#
# Concept 21:
# executor
# bank
# obliter
# applic
# radiant
# secretariesgener
# terminolog
# herbarium
# emplan
# font
#
# Concept 22:
# entireti
# applic
# acquir
# emplan
# invert
# associ
# subsidiari
# insul
# loadcarri
# lend
#
# Concept 23:
# exponentialtimeaverag
# alloc
# miner
# proclaim
# commiss
# price
# italic
# tankless
# quarterli
# scare
#
# Concept 24:
# perpendicular
# canadian
# propan
# secretariesgener
# miner
# progeni
# canada
# could
# lever
# claim
#
# Concept 25:
# commiss
# urin
# lamproom
# bank
# parliament
# permafrost
# anoth
# proclaim
# deutsch
# executor
#
# Concept 26:
# version
# exponentialtimeaverag
# vin
# board
# parliament
# permafrost
# obliter
# alloc
# notch
# seri
#
# Concept 27:
# fednav
# librarian
# tankless
# italic
# applic
# permafrost
# version
# bank
# judaic
# israel
#
# Concept 28:
# commiss
# implic
# librarian
# licens
# plywood
# author
# obliter
# radiant
# forklift
# groundsourc
#
# Concept 29:
# fednav
# pave
# implic
# version
# target
# insul
# custodian
# dustproof
# protrud
# paddleboat
#
# Concept 30:
# version
# commiss
# prereconsolid
# purg
# font
# groundsourc
# canadian
# hm
# class
# lever
#
# Concept 31:
# vin
# librarian
# secretari
# act
# amend
# gone
# amount
# proven
# contravent
# repaint
#
# Concept 32:
# area
# judaic
# lever
# activ
# applic
# proclaim
# placement
# vin
# miner
# desert
#
# Concept 33:
# repaint
# miner
# emplan
# version
# act
# legion
# enabl
# claim
# implic
# italic
#
# Concept 34:
# influenza
# megagram
# seriou
# protrud
# author
# regim
# prototyp
# offenc
# eldorado
# fold
#
# Concept 35:
# repaint
# legion
# enabl
# area
# exponentialtimeaverag
# offenc
# ventur
# associ
# seriou
# megagram
#
# Concept 36:
# groundsourc
# openhopp
# narcot
# herbarium
# defect
# seriou
# categori
# oviduct
# target
# deput
#
# Concept 37:
# megagram
# secretari
# paper
# class
# scare
# permafrost
# amend
# committe
# dustproof
# board
#
# Concept 38:
# ventur
# performancediminish
# custodian
# version
# virtu
# juic
# claim
# notch
# miner
# scare
#
# Concept 39:
# associ
# exponentialtimeaverag
# secretariesgener
# juic
# parliament
# effac
# april
# narcot
# prototyp
# seriou
#
# Concept 40:
# notif
# fednav
# herbarium
# narcot
# ventur
# activ
# notch
# inboard
# font
# canada
#
# Concept 41:
# associ
# notif
# secretariesgener
# groundsourc
# tankless
# amount
# openhopp
# vin
# categori
# perpendicular
#
# Concept 42:
# associ
# notif
# implic
# offenc
# proclaim
# sunset
# subrul
# inquir
# secretariesgener
# instead
#
# Concept 43:
# occurr
# corpor
# vin
# claim
# insul
# exponentialtimeaverag
# produc
# custodian
# depon
# instead
#
# Concept 44:
# juic
# notif
# area
# obviou
# grown
# oviduct
# effac
# megagram
# protrud
# insul
#
# Concept 45:
# seriou
# librarian
# eldorado
# notif
# commiss
# pencil
# contributor
# licens
# loadcarri
# defect
#
# Concept 46:
# juic
# repaint
# instead
# effac
# produc
# canada
# condit
# tactic
# raft
# seriou
#
# Concept 47:
# juic
# herbarium
# associ
# corpor
# inboard
# tankless
# lima
# protrud
# version
# author
#
# Concept 48:
# associ
# activ
# seriou
# depon
# marihuana
# vin
# occurr
# commiss
# area
# mileag
#
# Concept 49:
# corpor
# eldorado
# shaft
# pencil
# inboard
# contributor
# amend
# herbarium
# prereconsolid
# occurr
#
# Concept 50:
# interdepartment
# propan
# version
# rapidli
# custodian
# loadcarri
# librarian
# april
# readi
# influenza
#
# Concept 51:
# tankless
# firealarm
# repaint
# fold
# custodian
# author
# occurr
# secretari
# loadcarri
# subrul
#
# Concept 52:
# fednav
# ventur
# megagram
# juic
# defect
# narcot
# associ
# emplan
# vin
# paddleboat
#
# Concept 53:
# occurr
# bylaw
# deed
# notif
# juic
# implic
# perpendicular
# italic
# loadcarri
# target
#
# Concept 54:
# loadcarri
# ventur
# commiss
# desert
# board
# fednav
# firstclass
# virtu
# yacht
# canada
#
# Concept 55:
# occurr
# april
# firstclass
# yacht
# firealarm
# insul
# scare
# legion
# prereconsolid
# protrud
#
# Concept 56:
# ventur
# produc
# legion
# insert
# virtu
# paper
# purg
# class
# organis
# subrul
#
# Concept 57:
# firealarm
# loadcarri
# produc
# amend
# regim
# area
# seriou
# commiss
# charg
# board
#
# Concept 58:
# inquir
# sunset
# produc
# inboard
# parcel
# permafrost
# amount
# perpendicular
# mileag
# tankless
#
# Concept 59:
# miner
# occurr
# associ
# protrud
# produc
# vin
# fold
# juic
# sunset
# inquir
#
# Concept 60:
# firealarm
# deceas
# performancediminish
# hm
# amnesti
# occurr
# author
# act
# inspector
# medium
#
# Concept 61:
# judaic
# narcot
# exponentialtimeaverag
# produc
# replenish
# inquir
# offenc
# instead
# secretari
# firmli
#
# Concept 62:
# loadcarri
# subrul
# tundra
# deceas
# vin
# borrow
# juic
# fednav
# raft
# legion
#
# Concept 63:
# target
# mileag
# amnesti
# firealarm
# performancediminish
# permafrost
# seriou
# canadian
# corpor
# influenza
#
# Concept 64:
# sheriff
# target
# doctor
# certif
# author
# eldorado
# performancediminish
# commiss
# associ
# medium
#
# Concept 65:
# sheriff
# mileag
# reentri
# enabl
# amount
# fiscal
# canadian
# depon
# tundra
# area
#
# Concept 66:
# sheriff
# mileag
# canada
# defect
# inquir
# canadian
# employ
# wast
# emplan
# influenza
#
# Concept 67:
# firealarm
# offenc
# corpor
# amount
# certif
# shaft
# fold
# employ
# jammer
# capit
#
# Concept 68:
# certif
# openhopp
# paper
# lamproom
# class
# program
# enabl
# board
# occurr
# rescu
#
# Concept 69:
# amend
# interdepartment
# deceas
# author
# psig
# class
# valenc
# readi
# legion
# function
#
# Concept 70:
# sheriff
# park
# pigment
# secretari
# author
# fold
# ventur
# scare
# replenish
# inquir
#
# Concept 71:
# affili
# author
# gone
# jammer
# judaic
# april
# disclaim
# intermod
# lima
# valenc
#
# Concept 72:
# jammer
# amend
# depon
# reconsolid
# performancediminish
# vin
# sheriff
# instead
# fiscal
# terminolog
#
# Concept 73:
# jammer
# amend
# secretariesgener
# tundra
# deadweight
# subrul
# canada
# mileag
# judaic
# commod
#
# Concept 74:
# mileag
# fold
# openhopp
# perpendicular
# firealarm
# miner
# act
# park
# subrul
# fiscal
#
# Concept 75:
# affili
# paper
# psig
# program
# openhopp
# notch
# disclaim
# april
# counti
# depon
#
# Concept 76:
# doctor
# electromagnet
# fiscal
# addresse
# jammer
# secretariesgener
# april
# inquir
# protrud
# deadweight
#
# Concept 77:
# april
# tundra
# secretariesgener
# deadweight
# sheriff
# certif
# commiss
# miner
# purpos
# interdepartment
#
# Concept 78:
# tundra
# firealarm
# produc
# act
# commiss
# indisposit
# eldorado
# openhopp
# addresse
# adapt
#
# Concept 79:
# sheriff
# deceas
# charg
# openhopp
# vin
# amend
# agreement
# sparkproduc
# judaic
# seriou
#
# Concept 80:
# account
# advanc
# offenc
# subrul
# fold
# hm
# commiss
# openhopp
# produc
# fiscal
#
# Concept 81:
# jammer
# corpor
# secretari
# regim
# employ
# repaint
# certif
# forego
# occurr
# propan
#
# Concept 82:
# herbarium
# appeal
# featur
# deadweight
# account
# yacht
# advanc
# sheriff
# subrul
# inquir
#
# Concept 83:
# april
# hm
# corpor
# class
# forego
# notch
# regim
# reserv
# addresse
# terminolog
#
# Concept 84:
# mileag
# appeal
# assess
# sheriff
# firstclass
# prioriti
# amnesti
# program
# lavatori
# counti
#
# Concept 85:
# mileag
# medium
# class
# appeal
# advanc
# offenc
# volum
# instead
# electromagnet
# shaft
#
# Concept 86:
# commod
# vat
# learn
# miner
# eg
# inquir
# firealarm
# paper
# program
# agreement
#
# Concept 87:
# april
# raft
# replenish
# agenc
# canadian
# fednav
# inboard
# agreement
# reentri
# polar
#
# Concept 88:
# eg
# vat
# commod
# protrud
# deceas
# affili
# postsent
# licens
# medium
# desert
#
# Concept 89:
# featur
# amnesti
# corpor
# performancediminish
# certif
# mileag
# judaic
# eg
# raft
# openhopp
#
# Concept 90:
# learn
# prioriti
# megagram
# lend
# judaic
# doctor
# amnesti
# less
# für
# amend
#
# Concept 91:
# featur
# eg
# draw
# trent
# yacht
# shaft
# chicken
# capit
# regul
# proclaim
#
# Concept 92:
# corpor
# featur
# deadweight
# vat
# vault
# account
# fiscal
# scare
# commod
# advanc
#
# Concept 93:
# enabl
# replenish
# eg
# fednav
# reconsolid
# author
# perpendicular
# millisievert
# chicken
# judaic
#
# Concept 94:
# produc
# secretari
# jammer
# sheriff
# corpor
# band
# trent
# doctor
# insul
# reusabl
#
# Concept 95:
# vat
# firstclass
# crossventil
# enabl
# placement
# function
# resolv
# act
# lever
# tankless
#
# Concept 96:
# park
# shaft
# tundra
# sheriff
# shall
# psig
# adapt
# notic
# scoop
# ignitionprotect
#
# Concept 97:
# featur
# amend
# class
# offenc
# benefit
# desert
# draw
# scoop
# notic
# certif
#
# Concept 98:
# account
# corpor
# advanc
# april
# propan
# sheriff
# offenc
# paddleboat
# protrud
# tire
#
# Concept 99:
# program
# class
# assess
# featur
# agenc
# eldorado
# regim
# hm
# contributor
# activ

# %%
list_concepts = []
    
for i in range(0,len(lsa.components_)):
    list_concepts.append('Concept %d' %i)
    
df_lsa = pd.DataFrame(dtm_lsa, columns=list_concepts)

#df_lsa

# %% [markdown]
# ###### Document Similarity using LSA

# %%
df_norm = Normalizer(copy=False).fit_transform(dtm_lsa)

# %%
similarity = np.asarray(np.asmatrix(df_norm) * np.asmatrix(df_norm).T)
regs = list(dataset['instrument_number'])

# %%
df_heatmap = pd.DataFrame(similarity,index=regs, columns=regs)

# %%
#df_heatmap

# %% [markdown]
# ## 5. Extracting the highly similar documents

# %%
#minimum score/value for regulations to be considered similar
thresh_min = 0.95

#max score/value, above which regulations are the same document
thresh_max = 0.999999

# %%
#column names 
regs = df_heatmap.columns

#master list of similar regs to append to
similar_regs = []

#analyze each column's scores one at a time
for reg_1 in regs:
    reg_1_scores = df_heatmap[reg_1]
    
    #track the index value (integer) which meet the criteria
    index_value = 0
    list_index = []

    for score in reg_1_scores:
        if (score > thresh_min and score < thresh_max):
            list_index.append(index_value)
        index_value += 1
    
    #track the reg pairs which exceed the criteria - check for duplicates
    for i in list_index:
        reg_2 = df_heatmap.index[i]
        
        if [reg_2,reg_1] not in similar_regs:
            similar_regs.append([reg_1,reg_2])

# %% [markdown]
# ##### Checking the outputs

# %% [markdown]
# Given that the formula for the number of possible cominations where order doesn't matter:
#
# C(n,r)=n!/(n−r)!r!

# %%
import math
comb = int(math.factorial(len(df_heatmap))/(math.factorial((len(df_heatmap)-2))*math.factorial(2)))
print ('total combinations is: ' + str(comb))
# Out:
# total combinations is: 2584401

# %%
print ('Number of reg pairs over the threshold: ' + str(len(similar_regs)))
print ('Percent of reg pairs over the threshold: ' + str(len(similar_regs)/comb*100) + '%')
# Out:
# Number of reg pairs over the threshold: 4880
# Percent of reg pairs over the threshold: 0.18882518618434213%

# %% [markdown]
# ## Which Lebels in the Regs are Most Similar?

# %%
#convert the nested list into a DataFrame
reg_1 = []
reg_2 = []

for pair in similar_regs:
    reg_1.append(pair[0])
    reg_2.append(pair[1])

d = {'Reg_1':reg_1, 'Reg_2':reg_2}    
df_similar = pd.DataFrame(data=d)

# %%
df_similar
# Out:
#              Reg_1           Reg_2
# 0       SOR/93-293      SOR/93-522
# 1       SOR/93-293    SOR/2002-138
# 2       SOR/93-293      SOR/95-558
# 3       SOR/93-293      SOR/78-771
# 4       SOR/93-293      SOR/93-524
# 5       SOR/93-293   C.R.C., c. 83
# 6       SOR/93-293      SOR/87-706
# 7       SOR/93-293       SOR/93-74
# 8       SOR/93-293      SOR/80-803
# 9       SOR/93-293      SOR/93-409
# 10      SOR/93-293      SOR/93-408
# 11      SOR/93-293      SOR/93-387
# 12      SOR/93-293      SOR/88-509
# 13      SOR/93-293      SOR/80-902
# 14      SOR/93-293      SOR/96-401
# 15      SOR/93-293      SOR/91-253
# 16      SOR/93-293      SOR/99-123
# 17      SOR/93-293  C.R.C., c. 125
# 18      SOR/93-293  C.R.C., c. 114
# 19      SOR/93-293  C.R.C., c. 117
# 20      SOR/93-293  C.R.C., c. 116
# 21      SOR/93-293      SOR/95-495
# 22      SOR/93-293      SOR/94-123
# 23      SOR/93-293  C.R.C., c. 113
# 24      SOR/93-293      SOR/94-241
# 25      SOR/93-293      SOR/94-121
# 26      SOR/93-293      SOR/93-410
# 27      SOR/93-293   C.R.C., c. 98
# 28      SOR/93-293      SOR/94-556
# 29      SOR/93-293      SOR/91-173
# ...            ...             ...
# 4850    SOR/91-173      SOR/96-133
# 4851    SOR/91-173      SOR/92-649
# 4852    SOR/91-173      SOR/92-648
# 4853    SOR/91-173      SOR/87-453
# 4854    SOR/91-173    SOR/2004-212
# 4855    SOR/91-173      SOR/91-172
# 4856    SOR/88-574      SOR/88-575
# 4857    SOR/98-206      SOR/98-207
# 4858    SOR/81-167      SOR/96-133
# 4859    SOR/81-167      SOR/85-184
# 4860    SOR/81-167      SOR/92-649
# 4861    SOR/81-167      SOR/92-648
# 4862    SOR/81-167      SOR/87-453
# 4863    SOR/81-167      SOR/91-172
# 4864    SOR/96-133      SOR/85-184
# 4865    SOR/96-133      SOR/92-649
# 4866    SOR/96-133      SOR/92-648
# 4867    SOR/96-133      SOR/87-453
# 4868    SOR/96-133      SOR/91-172
# 4869    SOR/85-184      SOR/92-649
# 4870    SOR/85-184      SOR/92-648
# 4871    SOR/85-184      SOR/87-453
# 4872    SOR/85-184      SOR/91-172
# 4873    SOR/88-400      SOR/88-399
# 4874    SOR/92-649      SOR/92-648
# 4875    SOR/92-649      SOR/87-453
# 4876    SOR/92-648      SOR/87-453
# 4877    SOR/92-648      SOR/91-172
# 4878    SOR/87-453      SOR/91-172
# 4879  SOR/2004-212    SOR/2009-231
#
# [4880 rows x 2 columns]

# %% [markdown]
# # Testing how to compare Labels - LSA

# %%
#Set the target regs to compare
reg1 = 'SOR/93-293'
reg2 = 'SOR/93-522'

#Locate the target regs from the dataframe
df_reg1 = dataset[dataset['instrument_number']==reg1]
df_reg2 = dataset[dataset['instrument_number']==reg2]

#Extract the body text from both regs
reg1_body = list(df_reg1['section_bodies'])
reg2_body = list(df_reg2['section_bodies'])

#Extract the labels from both regs
reg1_labels = list(df_reg1['section_labels'])
reg2_labels = list(df_reg2['section_labels'])

# %%
#extract all the text between singular quotes because each set of quoates is a new section (or subsection) 
quoted  = re.compile("'[^']*'")
reg1_body_clean = []
reg2_body_clean = []

for section in quoted.findall(str(reg1_body)):
    reg1_body_clean.append(section)
    
for section in quoted.findall(str(reg2_body)):
    reg2_body_clean.append(section)

#Extract the section labels for each regs body (note the values are also stored between quotes)
## Also note that none include 'Label 1' so it must be added
reg1_labels_clean = [reg1 + ' Label: 1']
reg2_labels_clean = [reg2 + ' Label: 1']

for num in quoted.findall(str(reg1_labels)):
    reg1_labels_clean.append(reg1 + ' Label: ' + num.strip("'"))
    
for num in quoted.findall(str(reg2_labels)):
    reg2_labels_clean.append(reg2 + ' Label: ' + num.strip("'"))

# %%
#Combine the body and label lists and convert to a dataframe 
combined_body = []
combined_body.extend(reg1_body_clean)
combined_body.extend(reg2_body_clean)

combined_labels = []
combined_labels.extend(reg1_labels_clean)
combined_labels.extend(reg2_labels_clean)

df_similar_regs = pd.DataFrame(data={'Reg_Label':combined_labels, 'Text':combined_body})

# %%
df_similar_regs
# Out:
#               Reg_Label                                               Text
# 0   SOR/93-293 Label: 1                            'In these Regulations,'
# 1   SOR/93-293 Label: 2  'For the purposes of these Regulations, the el...
# 2   SOR/93-293 Label: 3  'These Regulations apply in respect of all lan...
# 3   SOR/93-293 Label: 4  'No person shall erect or construct on any lan...
# 4   SOR/93-293 Label: 5  'No owner or lessee of any lands in respect of...
# 5   SOR/93-293 Label: 6  'In order to minimize bird hazards to aviation...
# 6   SOR/93-522 Label: 1                            'In these Regulations,'
# 7   SOR/93-522 Label: 2  'For the purposes of these Regulations, the el...
# 8   SOR/93-522 Label: 3  'These Regulations apply to all land, includin...
# 9   SOR/93-522 Label: 4  'No person shall erect or construct, on any la...
# 10  SOR/93-522 Label: 5  'No owner or lessee of any land to which these...
# 11  SOR/93-522 Label: 6  'Where an object of natural growth that is on ...

# %%
#Apply the corpus creating function
filtered_text_label, stemmed_text_label = make_corpus(df_similar_regs,'Text')
# Out:
# Creating Corpus.. Processing Record: 12 of 12
# DONE!

# %%
cv_label = CountVectorizer()
X_label = cv_label.fit_transform(stemmed_text_label).toarray()

# %%
df_sparse_label = pd.DataFrame(X_label, columns = cv_label.get_feature_names())

# %%
#Words in the corpus
features_label = pd.Series(df_sparse_label.columns)

#Apply the has number function to see which features are numeric (true or false)
index_label = features_label.map(hasNumbers)

#Create a list of the features which are numeric ('True')
dropped_features_label = features_label[index_label]

#Drop the numeric features
df_sparse_label = df_sparse_label.drop(columns=dropped_features_label)

# %%
#Apply TF-IDF Weighting
transformer_label = TfidfTransformer()
tfidf_label = transformer_label.fit_transform(df_sparse_label).toarray()

# %%
#Document similarity using LSA
lsa_label = TruncatedSVD(n_components = 2, algorithm='arpack', random_state=0)
dtm_lsa_label = lsa_label.fit_transform(tfidf_label)

# %%
list_concepts_label = []
    
for i in range(0,len(lsa_label.components_)):
    list_concepts_label.append('Concept %d' %i)
    
df_lsa_label = pd.DataFrame(dtm_lsa_label, columns=list_concepts_label)

# %%
df_norm_label = Normalizer(copy=False).fit_transform(dtm_lsa_label)

# %%
df_norm_label
# Out:
# array([[ 0.59241745,  0.80563116],
#        [ 0.85550751,  0.5177904 ],
#        [ 0.99783276, -0.06580112],
#        [ 0.76398468, -0.64523439],
#        [ 0.8842798 , -0.46695743],
#        [ 0.93281266, -0.36036169],
#        [ 0.59241745,  0.80563116],
#        [ 0.85550751,  0.5177904 ],
#        [ 0.99997434,  0.00716416],
#        [ 0.79832868, -0.60222198],
#        [ 0.93590037, -0.35226481],
#        [ 0.88071419, -0.47364808]])

# %%
similarity_label = np.asarray(np.asmatrix(df_norm_label) * np.asmatrix(df_norm_label).T)

# %%
regs_label = list(df_similar_regs['Reg_Label'])

# %%
df_heatmap_label = pd.DataFrame(similarity_label,index=regs_label, columns=regs_label)

# %%
df_heatmap_label
# Out:
#                      SOR/93-293 Label: 1  SOR/93-293 Label: 2  \
# SOR/93-293 Label: 1             1.000000             0.923966
# SOR/93-293 Label: 2             0.923966             1.000000
# SOR/93-293 Label: 3             0.538122             0.819582
# SOR/93-293 Label: 4            -0.067223             0.319498
# SOR/93-293 Label: 5             0.147667             0.514722
# SOR/93-293 Label: 6             0.262296             0.611436
# SOR/93-522 Label: 1             1.000000             0.923966
# SOR/93-522 Label: 2             0.923966             1.000000
# SOR/93-522 Label: 3             0.598174             0.859195
# SOR/93-522 Label: 4            -0.012225             0.371151
# SOR/93-522 Label: 5             0.270648             0.618270
# SOR/93-522 Label: 6             0.140165             0.508207
#
#                      SOR/93-293 Label: 3  SOR/93-293 Label: 4  \
# SOR/93-293 Label: 1             0.538122            -0.067223
# SOR/93-293 Label: 2             0.819582             0.319498
# SOR/93-293 Label: 3             1.000000             0.804786
# SOR/93-293 Label: 4             0.804786             1.000000
# SOR/93-293 Label: 5             0.913090             0.976873
# SOR/93-293 Label: 6             0.954503             0.945172
# SOR/93-522 Label: 1             0.538122            -0.067223
# SOR/93-522 Label: 2             0.819582             0.319498
# SOR/93-522 Label: 3             0.997336             0.759343
# SOR/93-522 Label: 4             0.836225             0.998485
# SOR/93-522 Label: 5             0.957051             0.942307
# SOR/93-522 Label: 6             0.909972             0.978466
#
#                      SOR/93-293 Label: 5  SOR/93-293 Label: 6  \
# SOR/93-293 Label: 1             0.147667             0.262296
# SOR/93-293 Label: 2             0.514722             0.611436
# SOR/93-293 Label: 3             0.913090             0.954503
# SOR/93-293 Label: 4             0.976873             0.945172
# SOR/93-293 Label: 5             1.000000             0.993141
# SOR/93-293 Label: 6             0.993141             1.000000
# SOR/93-522 Label: 1             0.147667             0.262296
# SOR/93-522 Label: 2             0.514722             0.611436
# SOR/93-522 Label: 3             0.880912             0.930207
# SOR/93-522 Label: 4             0.987158             0.961709
# SOR/93-522 Label: 5             0.992090             0.999962
# SOR/93-522 Label: 6             0.999971             0.992226
#
#                      SOR/93-522 Label: 1  SOR/93-522 Label: 2  \
# SOR/93-293 Label: 1             1.000000             0.923966
# SOR/93-293 Label: 2             0.923966             1.000000
# SOR/93-293 Label: 3             0.538122             0.819582
# SOR/93-293 Label: 4            -0.067223             0.319498
# SOR/93-293 Label: 5             0.147667             0.514722
# SOR/93-293 Label: 6             0.262296             0.611436
# SOR/93-522 Label: 1             1.000000             0.923966
# SOR/93-522 Label: 2             0.923966             1.000000
# SOR/93-522 Label: 3             0.598174             0.859195
# SOR/93-522 Label: 4            -0.012225             0.371151
# SOR/93-522 Label: 5             0.270648             0.618270
# SOR/93-522 Label: 6             0.140165             0.508207
#
#                      SOR/93-522 Label: 3  SOR/93-522 Label: 4  \
# SOR/93-293 Label: 1             0.598174            -0.012225
# SOR/93-293 Label: 2             0.859195             0.371151
# SOR/93-293 Label: 3             0.997336             0.836225
# SOR/93-293 Label: 4             0.759343             0.998485
# SOR/93-293 Label: 5             0.880912             0.987158
# SOR/93-293 Label: 6             0.930207             0.961709
# SOR/93-522 Label: 1             0.598174            -0.012225
# SOR/93-522 Label: 2             0.859195             0.371151
# SOR/93-522 Label: 3             1.000000             0.793994
# SOR/93-522 Label: 4             0.793994             1.000000
# SOR/93-522 Label: 5             0.933353             0.959298
# SOR/93-522 Label: 6             0.877298             0.988341
#
#                      SOR/93-522 Label: 5  SOR/93-522 Label: 6
# SOR/93-293 Label: 1             0.270648             0.140165
# SOR/93-293 Label: 2             0.618270             0.508207
# SOR/93-293 Label: 3             0.957051             0.909972
# SOR/93-293 Label: 4             0.942307             0.978466
# SOR/93-293 Label: 5             0.992090             0.999971
# SOR/93-293 Label: 6             0.999962             0.992226
# SOR/93-522 Label: 1             0.270648             0.140165
# SOR/93-522 Label: 2             0.618270             0.508207
# SOR/93-522 Label: 3             0.933353             0.877298
# SOR/93-522 Label: 4             0.959298             0.988341
# SOR/93-522 Label: 5             1.000000             0.991110
# SOR/93-522 Label: 6             0.991110             1.000000

# %%
sns.heatmap(df_heatmap_label)

# %%
#Which sections are the most similar within the target regulations?

#minimum score/value for reg labels to be considered similar
thresh_min = 0.98

#max score/value, above which reg labels are identical
thresh_max = 0.999999

#label names
reg_labels = df_heatmap_label.columns

#master list of similar regs to append to
similar_regs_label = []

#analyze each column's scores one at a time
for reg_1_label in reg_labels:
    reg_1_label_scores = df_heatmap_label[reg_1_label]
    
    #track the index value (integer) which meet the criteria
    index_value = 0
    list_index = []
    #list_score = []

    for score in reg_1_label_scores:
        if (score > thresh_min and score < thresh_max):
            list_index.append(index_value)
            #list_score.append(score)
            
        index_value += 1
    
    #track the reg pairs which exceed the criteria - check for duplicates
    for i in list_index:
        reg_2_label = df_heatmap_label.index[i]
        
        if [reg_2_label, reg_1_label, reg_1_label_scores[i]] not in similar_regs_label:
            similar_regs_label.append([reg_1_label, reg_2_label, reg_1_label_scores[i]])

# %%
similar_regs_label
# Out:
# [['SOR/93-293 Label: 3', 'SOR/93-522 Label: 3', 0.9973357405213998],
#  ['SOR/93-293 Label: 4', 'SOR/93-522 Label: 4', 0.9984852112611297],
#  ['SOR/93-293 Label: 5', 'SOR/93-293 Label: 6', 0.9931409545853597],
#  ['SOR/93-293 Label: 5', 'SOR/93-522 Label: 4', 0.9871579531933474],
#  ['SOR/93-293 Label: 5', 'SOR/93-522 Label: 5', 0.9920904597897454],
#  ['SOR/93-293 Label: 5', 'SOR/93-522 Label: 6', 0.999971260828653],
#  ['SOR/93-293 Label: 6', 'SOR/93-522 Label: 5', 0.999962453309477],
#  ['SOR/93-293 Label: 6', 'SOR/93-522 Label: 6', 0.9922259715188082],
#  ['SOR/93-522 Label: 4', 'SOR/93-522 Label: 6', 0.9883406895422315],
#  ['SOR/93-522 Label: 5', 'SOR/93-522 Label: 6', 0.9911102937832119]]

# %%
comb = int(math.factorial(len(df_heatmap_label))/(math.factorial((len(df_heatmap_label)-2))*math.factorial(2)))
print ('total combinations is: ' + str(comb))
# Out:
# total combinations is: 66

# %%
print ('Number of reg pairs over the threshold: ' + str(len(similar_regs_label)))
print ('Percent of reg pairs over the threshold: ' + str(len(similar_regs_label)/comb*100) + '%')
# Out:
# Number of reg pairs over the threshold: 10
# Percent of reg pairs over the threshold: 15.151515151515152%

# %%
#convert output to a dataframe 
label_A = []
label_B = []
score = []

for entry in similar_regs_label:
    label_A.append(entry[0])
    label_B.append(entry[1])
    score.append(entry[2])

df_similar_regs_label = pd.DataFrame(data={'Label_A':label_A, 'Label_B':label_B, 'Score':score})

# %%
df_similar_regs_label
# Out:
#                Label_A              Label_B     Score
# 0  SOR/93-293 Label: 3  SOR/93-522 Label: 3  0.997336
# 1  SOR/93-293 Label: 4  SOR/93-522 Label: 4  0.998485
# 2  SOR/93-293 Label: 5  SOR/93-293 Label: 6  0.993141
# 3  SOR/93-293 Label: 5  SOR/93-522 Label: 4  0.987158
# 4  SOR/93-293 Label: 5  SOR/93-522 Label: 5  0.992090
# 5  SOR/93-293 Label: 5  SOR/93-522 Label: 6  0.999971
# 6  SOR/93-293 Label: 6  SOR/93-522 Label: 5  0.999962
# 7  SOR/93-293 Label: 6  SOR/93-522 Label: 6  0.992226
# 8  SOR/93-522 Label: 4  SOR/93-522 Label: 6  0.988341
# 9  SOR/93-522 Label: 5  SOR/93-522 Label: 6  0.991110
