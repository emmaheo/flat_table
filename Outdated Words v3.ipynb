# %% [markdown]
# ### 1. Importing Packages, DF Set-up, Defining Outdated Tech/Processes

# %%
import re
import numpy as np
import pandas as pd
import xml.etree.ElementTree
from lxml import etree
import os
import io

#Hide Future Version warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

#show all the columns when dataframes are displayed
pd.set_option('display.max_columns', 500)

# %%
#Using the original flat table
df = pd.read_excel("AI_Reg_Flat_Table_V3_Part1.xlsx")

# %%
df
# Out:
#      Instrumentation_Num Registration_Date Consolidation_Date Last_Mod_Date  \
# 0          C.R.C., c. 10               NaN         06/21/2018    05/26/2005
# 1         C.R.C., c. 100               NaN         06/21/2018     6/23/2005
# 2         C.R.C., c. 101               NaN         06/21/2018     2/24/2012
# 3        C.R.C., c. 1013               NaN         06/21/2018     7/19/2005
# 4        C.R.C., c. 1015               NaN         06/21/2018     7/19/2005
# 5         C.R.C., c. 102               NaN         06/21/2018     2/24/2012
# 6        C.R.C., c. 1021               NaN         06/21/2018     7/19/2005
# 7        C.R.C., c. 1022               NaN         06/21/2018     7/21/2005
# 8        C.R.C., c. 1023               NaN         06/21/2018    10/17/2007
# 9        C.R.C., c. 1026               NaN         06/21/2018     7/19/2005
# 10       C.R.C., c. 1027               NaN         06/21/2018     9/30/2010
# 11        C.R.C., c. 103               NaN         06/21/2018     2/24/2012
# 12       C.R.C., c. 1033               NaN         06/21/2018     7/19/2005
# 13       C.R.C., c. 1035               NaN         06/21/2018      3/7/2006
# 14       C.R.C., c. 1036               NaN         06/21/2018      5/3/2006
# 15       C.R.C., c. 1038               NaN         06/21/2018     4/26/2006
# 16        C.R.C., c. 104               NaN         06/21/2018     2/27/2012
# 17       C.R.C., c. 1041               NaN         06/21/2018    10/12/2010
# 18       C.R.C., c. 1044               NaN         06/21/2018     7/19/2005
# 19       C.R.C., c. 1045               NaN         06/21/2018     7/19/2005
# 20       C.R.C., c. 1046               NaN         06/21/2018           NaN
# 21       C.R.C., c. 1048               NaN         06/21/2018     7/19/2005
# 22       C.R.C., c. 1049               NaN         06/21/2018     6/29/2005
# 23        C.R.C., c. 105               NaN         06/21/2018     2/27/2012
# 24       C.R.C., c. 1050               NaN         06/21/2018     7/19/2005
# 25       C.R.C., c. 1055               NaN         06/21/2018     7/19/2005
# 26       C.R.C., c. 1058               NaN         06/21/2018     2/16/2010
# 27        C.R.C., c. 106               NaN         06/21/2018     2/27/2012
# 28        C.R.C., c. 109               NaN         06/21/2018     2/27/2012
# 29       C.R.C., c. 1105               NaN         06/21/2018     7/19/2005
# ...                  ...               ...                ...           ...
# 3169          SOR/99-295         6/23/1999         06/21/2018     5/31/2006
# 3170          SOR/99-298         6/23/1999         06/21/2018     5/11/2006
# 3171            SOR/99-3        12/14/1998         06/21/2018     3/14/2008
# 3172          SOR/99-300         6/23/1999         06/21/2018    10/28/2008
# 3173          SOR/99-308          7/9/1999         06/21/2018    10/28/2008
# 3174          SOR/99-317         7/28/1999         06/21/2018     12/5/2008
# 3175          SOR/99-318         7/28/1999         06/21/2018    10/28/2008
# 3176          SOR/99-324         7/28/1999         06/21/2018      6/6/2005
# 3177          SOR/99-325         7/28/1999         06/21/2018      6/2/2006
# 3178          SOR/99-335         7/28/1999         06/21/2018    11/13/2007
# 3179          SOR/99-348         8/26/1999         06/21/2018    10/28/2008
# 3180          SOR/99-350         8/26/1999         06/21/2018    10/28/2008
# 3181          SOR/99-381         10/5/1999         06/21/2018     4/16/2008
# 3182          SOR/99-382         10/5/1999         06/21/2018     4/16/2008
# 3183          SOR/99-383         10/5/1999         06/21/2018    10/28/2008
# 3184          SOR/99-384         10/5/1999         06/21/2018     4/16/2008
# 3185          SOR/99-388         10/6/1999         06/21/2018     9/23/2005
# 3186            SOR/99-4        12/14/1998         06/21/2018     3/13/2008
# 3187          SOR/99-409        10/21/1999         06/21/2018    10/31/2008
# 3188          SOR/99-410        10/21/1999         06/21/2018    10/31/2008
# 3189          SOR/99-422        10/21/1999         06/21/2018     5/11/2006
# 3190          SOR/99-444        11/10/1999         06/21/2018           NaN
# 3191          SOR/99-451        11/25/1999         06/21/2018    10/31/2008
# 3192          SOR/99-460         12/2/1999         06/21/2018     5/29/2007
# 3193          SOR/99-467         12/9/1999         06/21/2018    10/22/2008
# 3194           SOR/99-53         1/15/1999         06/21/2018      7/5/2007
# 3195            SOR/99-7        12/16/1998         06/21/2018     4/26/2006
# 3196           SOR/99-86         2/10/1999         06/21/2018     9/26/2014
# 3197           SOR/99-93         2/11/1999         06/21/2018    10/21/2008
# 3198           SOR/99-94         2/11/1999         06/21/2018    10/21/2008
#
#                                      Enabling_Authority  \
# 0                                   ['AERONAUTICS ACT']
# 1                                   ['AERONAUTICS ACT']
# 2                                   ['AERONAUTICS ACT']
# 3                                ['CANADA LABOUR CODE']
# 4                ['FAIR WAGES AND HOURS OF LABOUR ACT']
# 5                                   ['AERONAUTICS ACT']
# 6                          ['CANADA LANDS SURVEYS ACT']
# 7           ['LIEUTENANT GOVERNORS SUPERANNUATION ACT']
# 8                             ['HEALTH OF ANIMALS ACT']
# 9                     ['LIVESTOCK FEED ASSISTANCE ACT']
# 10                    ['LIVESTOCK FEED ASSISTANCE ACT']
# 11                                  ['AERONAUTICS ACT']
# 12    ['MEMBERS OF PARLIAMENT RETIRING ALLOWANCES ACT']
# 13             ['MIGRATORY BIRDS CONVENTION ACT, 1994']
# 14             ['MIGRATORY BIRDS CONVENTION ACT, 1994']
# 15                         ['MOTOR VEHICLE SAFETY ACT']
# 16                                  ['AERONAUTICS ACT']
# 17              ['CONTROLLED DRUGS AND SUBSTANCES ACT']
# 18                             ['NATIONAL CAPITAL ACT']
# 19                             ['NATIONAL DEFENCE ACT']
# 20                             ['NATIONAL DEFENCE ACT']
# 21                             ['NATIONAL DEFENCE ACT']
# 22                             ['NATIONAL DEFENCE ACT']
# 23                                  ['AERONAUTICS ACT']
# 24                             ['NATIONAL DEFENCE ACT']
# 25                        ['NATIONAL ENERGY BOARD ACT']
# 26                        ['NATIONAL ENERGY BOARD ACT']
# 27                                  ['AERONAUTICS ACT']
# 28                                  ['AERONAUTICS ACT']
# 29                         ['DEPARTMENT OF HEALTH ACT']
# ...                                                 ...
# 3169            ['AGRICULTURAL MARKETING PROGRAMS ACT']
# 3170                          ['TERRITORIAL LANDS ACT']
# 3171  [['PUBLIC SERVICE SUPERANNUATION ACT', 'FINANC...
# 3172    ['FOREIGN PUBLISHERS ADVERTISING SERVICES ACT']
# 3173                              ['EXPROPRIATION ACT']
# 3174                                 ['CUSTOMS TARIFF']
# 3175          ['CANADIAN ENVIRONMENTAL ASSESSMENT ACT']
# 3176                                  ['COPYRIGHT ACT']
# 3177                                  ['COPYRIGHT ACT']
# 3178                      ['CANADA SHIPPING ACT, 2001']
# 3179                                  ['COPYRIGHT ACT']
# 3180  ['FOREIGN MISSIONS AND INTERNATIONAL ORGANIZAT...
# 3181       ['CANADA DEPOSIT INSURANCE CORPORATION ACT']
# 3182       ['CANADA DEPOSIT INSURANCE CORPORATION ACT']
# 3183       ['CANADA DEPOSIT INSURANCE CORPORATION ACT']
# 3184       ['CANADA DEPOSIT INSURANCE CORPORATION ACT']
# 3185                                       ['BANK ACT']
# 3186  [['PUBLIC SERVICE SUPERANNUATION ACT', 'FINANC...
# 3187  ['FOREIGN MISSIONS AND INTERNATIONAL ORGANIZAT...
# 3188        ['CANADIAN PEACEKEEPING SERVICE MEDAL ACT']
# 3189                          ['TERRITORIAL LANDS ACT']
# 3190                             ['UNITED NATIONS ACT']
# 3191               ['CANADA AGRICULTURAL PRODUCTS ACT']
# 3192                          ['INDUSTRIAL DESIGN ACT']
# 3193  ['CANADA TRAVELLING EXHIBITIONS INDEMNIFICATIO...
# 3194                      ['CANADA SHIPPING ACT, 2001']
# 3195    ['CANADIAN ENVIRONMENTAL PROTECTION ACT, 1999']
# 3196                            ['VISITING FORCES ACT']
# 3197                                    ['TOBACCO ACT']
# 3198                                    ['TOBACCO ACT']
#
#                                             Short_Title  \
# 0             Flying Accidents Compensation Regulations
# 1       Ottawa International Airport Zoning Regulations
# 2                  Penticton Airport Zoning Regulations
# 3     Canada Industrial Relations Remuneration Regul...
# 4                                                   NaN
# 5               Pitt Meadows Airport Zoning Regulations
# 6                                  Lands Surveys Tariff
# 7       Lieutenant Governors Superannuation Regulations
# 8                                  Hatchery Regulations
# 9     Canadian Livestock Feed Board Headquarters Reg...
# 10    Feed Grain Transportation and Storage Assistan...
# 11             Prince George Airport Zoning Regulations
# 12                                                  NaN
# 13                          Migratory Birds Regulations
# 14                 Migratory Bird Sanctuary Regulations
# 15                     Motor Vehicle Safety Regulations
# 16                    Quebec Airport Zoning Regulations
# 17                         Narcotic Control Regulations
# 18    National Capital Commission Traffic and Proper...
# 19    Canadian Forces Dental Treatment by Civilians ...
# 20        Civilian Crews on Auxiliary Vessels Direction
# 21                                  Estates Regulations
# 22                           Military Rules of Evidence
# 23                    Regina Airport Zoning Regulations
# 24            Reserve Forces Training Leave Regulations
# 25             National Energy Board Order No. MO-62-69
# 26          Oil Pipeline Uniform Accounting Regulations
# 27              Resolute Bay Airport Zoning Regulations
# 28          Sault Ste. Marie Airport Zoning Regulations
# 29        Potable Water Regulations for Common Carriers
# ...                                                 ...
# 3169                                                NaN
# 3170                                                NaN
# 3171                                                NaN
# 3172                                                NaN
# 3173                                                NaN
# 3174                                                NaN
# 3175                                                NaN
# 3176                                                NaN
# 3177                                                NaN
# 3178                           Private Buoy Regulations
# 3179                                                NaN
# 3180                                                NaN
# 3181                                                NaN
# 3182                                                NaN
# 3183                                                NaN
# 3184                                                NaN
# 3185                                                NaN
# 3186                                                NaN
# 3187                                                NaN
# 3188                                                NaN
# 3189                                                NaN
# 3190    United Nations Al-Qaida and Taliban Regulations
# 3191                                                NaN
# 3192                                                NaN
# 3193                                                NaN
# 3194                                                NaN
# 3195                                                NaN
# 3196                                                NaN
# 3197                                                NaN
# 3198                                                NaN
#
#                                              Long_Title Reg_Maker  \
# 0     Regulations Prescribing Compensation for Bodil...       NaN
# 1     Regulations Respecting Zoning at Ottawa Intern...       NaN
# 2     Regulations Respecting Zoning at Penticton Air...       NaN
# 3     Regulations Respecting the Remuneration and Ex...       NaN
# 4            Fair Wages and Hours of Labour Regulations       NaN
# 5     Regulations Respecting Zoning at Pitt Meadows ...       NaN
# 6     Tariff of Fees to be Charged by the Department...       NaN
# 7     Regulations Made Pursuant to the Lieutenant Go...       NaN
# 8     Regulations Respecting the Improvement of Poul...       NaN
# 9     Regulations Designating the Headquarters of th...       NaN
# 10    Regulations Prescribing Terms, Conditions and ...       NaN
# 11    Regulations Respecting Zoning at Prince George...       NaN
# 12    Members of Parliament Retiring Allowances Regu...       NaN
# 13    Regulations Respecting the Protection of Migra...       NaN
# 14    Regulations Prescribing Migratory Bird Sanctua...       NaN
# 15    Regulations Respecting Safety for Motor Vehicl...       NaN
# 16      Regulations Respecting Zoning at Quebec Airport       NaN
# 17      Regulations Respecting the Control of Narcotics       NaN
# 18    Regulations Respecting the Property of the Nat...       NaN
# 19    Regulations Respecting Dental Treatment by Civ...       NaN
# 20             {'XRefExternal': 'National Defence Act'}       NaN
# 21    Regulations Respecting the Administration and ...       NaN
# 22    Regulations Respecting the Rules of Evidence a...       NaN
# 23      Regulations Respecting Zoning at Regina Airport       NaN
# 24    Regulations Respecting Training Leave for Rese...       NaN
# 25    Order Respecting the Application of Part IV of...       NaN
# 26    Regulations Respecting the Uniform System of A...       NaN
# 27    Regulations Respecting Zoning at Resolute Bay ...       NaN
# 28    Regulations Respecting Zoning at Sault Ste. Ma...       NaN
# 29    Regulations Concerning Water for Drinking and ...       NaN
# ...                                                 ...       ...
# 3169        Agricultural Marketing Programs Regulations      P.C.
# 3170  Order Authorizing Federal Employees to Acquire...      P.C.
# 3171  Portions of the Department of Citizenship and ...      T.B.
# 3172  Regulations Defining Certain Expressions for t...      P.C.
# 3173                                    Tariff of Costs      P.C.
# 3174                        European Union Surtax Order      P.C.
# 3175  Canada Port Authority Environmental Assessment...      P.C.
# 3176                       Book Importation Regulations      P.C.
# 3177  Exceptions for Educational Institutions, Libra...      P.C.
# 3178                           Private Buoy Regulations      P.C.
# 3179   Regulations Prescribing Networks (Copyright Act)      P.C.
# 3180  Organization of American States Privileges and...      P.C.
# 3181  Exemption from Deposit Insurance By-law (Notic...       NaN
# 3182  Exemption from Deposit Insurance By-law (Exemp...       NaN
# 3183  Exemption from Deposit Insurance By-law (Inter...       NaN
# 3184  Exemption from Deposit Insurance By-law (Forei...       NaN
# 3185  Notices of Uninsured Deposits Regulations (Banks)      P.C.
# 3186  Blainville Motor Vehicle Test Centre Benefit E...      T.B.
# 3187  Order respecting Privileges and Immunities in ...      P.C.
# 3188  Canadian Peacekeeping Service Medal Award Regu...      P.C.
# 3189  Order Authorizing Federal Employees to Acquire...      P.C.
# 3190    United Nations Al-Qaida and Taliban Regulations      P.C.
# 3191  Rules of the Review Tribunal (Agriculture and ...      P.C.
# 3192                      Industrial Design Regulations      P.C.
# 3193  Canada Travelling Exhibitions Indemnification ...      P.C.
# 3194  Competency of Operators of Pleasure Craft Regu...      P.C.
# 3195       Ozone-Depleting Substances Regulations, 1998       P.C
# 3196  Proclamation Designating Certain Countries as ...       NaN
# 3197                       Tobacco (Access) Regulations      P.C.
# 3198      Tobacco (Seizure and Restoration) Regulations      P.C.
#
#      Reg_Order_Num Reg_Order_Maker_Date  \
# 0              NaN                  NaN
# 1              NaN                  NaN
# 2              NaN                  NaN
# 3              NaN                  NaN
# 4              NaN                  NaN
# 5              NaN                  NaN
# 6              NaN                  NaN
# 7              NaN                  NaN
# 8              NaN                  NaN
# 9              NaN                  NaN
# 10             NaN                  NaN
# 11             NaN                  NaN
# 12             NaN                  NaN
# 13             NaN                  NaN
# 14             NaN                  NaN
# 15             NaN                  NaN
# 16             NaN                  NaN
# 17             NaN                  NaN
# 18             NaN                  NaN
# 19             NaN                  NaN
# 20             NaN                  NaN
# 21             NaN                  NaN
# 22             NaN                  NaN
# 23             NaN                  NaN
# 24             NaN                  NaN
# 25             NaN                  NaN
# 26             NaN                  NaN
# 27             NaN                  NaN
# 28             NaN                  NaN
# 29             NaN                  NaN
# ...            ...                  ...
# 3169    1999-1186            6/23/ 1999
# 3170    1999-1204            6/23/ 1999
# 3171        826779           12/10/1998
# 3172    1999-1217            6/23/ 1999
# 3173    1999-1311             7/9/ 1999
# 3174    1999-1323            7/28/ 1999
# 3175    1999-1324            7/28/ 1999
# 3176     1999-1350            7/28/1999
# 3177    1999-1351            7/28/ 1999
# 3178    1999-1364             7/28/1999
# 3179    1999-1479            8/26/ 1999
# 3180    1999-1491            8/26/ 1999
# 3181           NaN                  NaN
# 3182           NaN                  NaN
# 3183           NaN                  NaN
# 3184           NaN                  NaN
# 3185     1999-1770            10/6/1999
# 3186        826779           12/10/1998
# 3187     1999-1850          10/21/ 1999
# 3188     1999-1858          10/21/ 1999
# 3189    1999-1885           10/21/ 1999
# 3190     1999-2015           11/10/1999
# 3191     1999-2082          11/25/ 1999
# 3192    1999-2135            12/2/ 1999
# 3193     1999-2163           12/9/ 1999
# 3194      1999-11            1/15/ 1999
# 3195     1998-2251           12/16/1998
# 3196           NaN                  NaN
# 3197      1999-197            2/11/1999
# 3198      1999-198           2/11/ 1999
#
#                                                Schedule  \
# 0                                                   NaN
# 1     [{'OriginatingRef': '(Sections 2 and 4)', 'Lab...
# 2     [{'OriginatingRef': '(Sections 2 and 4)', 'Lab...
# 3                                                   NaN
# 4                                                   NaN
# 5     [{'OriginatingRef': '(Sections 2 and 4)', 'Lab...
# 6     [{'OriginatingRef': '(Section 2)', 'Label': 'S...
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    [{'OriginatingRef': '(Sections 2 and 4)', 'Lab...
# 12    [{'OriginatingRef': '(Section 8)', 'Label': 'S...
# 13                                                  NaN
# 14    [{'OriginatingRef': '(s. 3)', 'Label': 'SCHEDU...
# 15                                                  NaN
# 16    [[{'Item': [{'Text': '112'}, {'Text': '112-1 t...
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23    [{'OriginatingRef': '(Sections 2 and 4)', 'Lab...
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27    [{'OriginatingRef': '(Sections 2 and 4)', 'Lab...
# 28    [{'OriginatingRef': '(Sections 2 and 4)', 'Lab...
# 29                                                  NaN
# ...                                                 ...
# 3169                                                NaN
# 3170  [{'Label': 'SCHEDULE'}, {'Text': 'To Roselle M...
# 3171                                                NaN
# 3172                                                NaN
# 3173                                                NaN
# 3174                                                NaN
# 3175                                                NaN
# 3176                                                NaN
# 3177                                                NaN
# 3178                                                NaN
# 3179                                                NaN
# 3180                                                NaN
# 3181                                                NaN
# 3182                                                NaN
# 3183                                                NaN
# 3184                                                NaN
# 3185  [{'Label': 'SCHEDULE'}, '[Repealed, SOR/2008-6...
# 3186                                                NaN
# 3187                                                NaN
# 3188                                                NaN
# 3189  [{'Label': 'SCHEDULE'}, {'Text': u'To Wayne An...
# 3190                                                NaN
# 3191                                                NaN
# 3192                                                NaN
# 3193                                                NaN
# 3194  [{'OriginatingRef': u'(Paragraph\xa03(2)(c) an...
# 3195                                                NaN
# 3196                                                NaN
# 3197                                                NaN
# 3198                                                NaN
#
#                                                   Order
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 3169  <Provision format-ref="indent-0-0" language-al...
# 3170  <Provision format-ref="indent-0-0" language-al...
# 3171  <Provision format-ref="indent-0-0" language-al...
# 3172  <Provision format-ref="indent-0-0" language-al...
# 3173  <Provision format-ref="indent-0-0" language-al...
# 3174  <Provision><Text><Repealed>[Repealed, SOR/2011...
# 3175  <Provision format-ref="indent-0-0" language-al...
# 3176  <Provision format-ref="indent-0-0" language-al...
# 3177  <Provision format-ref="indent-0-0" language-al...
# 3178  <Provision format-ref="indent-0-0" language-al...
# 3179  <Provision format-ref="indent-0-0" language-al...
# 3180  <Provision format-ref="indent-0-0" language-al...
# 3181  <Provision format-ref="indent-0-0" language-al...
# 3182  <Provision format-ref="indent-0-0" language-al...
# 3183  <Provision format-ref="indent-0-0" language-al...
# 3184  <Provision format-ref="indent-0-0" language-al...
# 3185  <Provision format-ref="indent-0-0" language-al...
# 3186  <Provision format-ref="indent-0-0" language-al...
# 3187  <Provision format-ref="indent-0-0" language-al...
# 3188  <Provision format-ref="indent-0-0" language-al...
# 3189  <Provision format-ref="indent-0-0" language-al...
# 3190  <Provision format-ref="indent-0-0" language-al...
# 3191  <Provision><Text><Repealed>[Repealed, SOR/2015...
# 3192  <Provision format-ref="indent-0-0" language-al...
# 3193  <Provision format-ref="indent-0-0" language-al...
# 3194  <Provision format-ref="indent-0-0" language-al...
# 3195  <Provision><Text><Repealed>[Repealed, SOR/2016...
# 3196  <Provision format-ref="indent-0-0" language-al...
# 3197  <Provision format-ref="indent-0-0" language-al...
# 3198  <Provision format-ref="indent-0-0" language-al...
#
# [3199 rows x 12 columns]

# %%
#Outdated items to search for 
list_outdated_tech = ['paper', 'print', 'mail', 'fax', 'pen', 'pencil', 'ink', 'carbon copy', 'hard copy', 
                      'original copy', 'on site','on-site', 'file', 'filing']

list_outdated_process = ['written', 'write', 'wrote', 'physical', 'proof', 'signed', 'in person', 'in-person', 
                         'notary', 'submission', 'non-electronic', 'non electronic', 
                         'document (excluding electronic)', 'excluding electronic', 'signature']

# %% [markdown]
# ### 2. Required (Helper) Fucntions

# %%
#Code to convert XML element tree to a dictionary
def make_dict_from_tree(element_tree):
    def internal_iter(tree, accum):
        if tree is None:
            return accum
        
        if tree.getchildren():
            accum[tree.tag] = {}
            for each in tree.getchildren():
                result = internal_iter(each, {})
                if each.tag in accum[tree.tag]:
                    if not isinstance(accum[tree.tag][each.tag], list):
                        accum[tree.tag][each.tag] = [
                            accum[tree.tag][each.tag]
                        ]
                    accum[tree.tag][each.tag].append(result[each.tag])
                else:
                    accum[tree.tag].update(result)
        else:
            accum[tree.tag] = tree.text
        return accum
    return internal_iter(element_tree, {})

# %%
#function to clean each body text
def body_clean(text):
    cleaned = text.replace("Text", "")
    cleaned = cleaned.replace("[", "")
    cleaned = cleaned.replace("]", "")
    cleaned = cleaned.replace("{", "")
    cleaned = cleaned.replace("}", "")
    return cleaned

#function to clean each label tag
def label_clean(text):
    cleaned = body_clean(text)
    cleaned = cleaned.replace("'", "")
    return cleaned

# %%
#function to help update dictionaries if a key does or does not exist
def set_key(dictionary, key, value):
    if key not in dictionary:
        dictionary[key] = value
        
    elif type(dictionary[key]) == list:
        dictionary[key].append(value)
        
    else:
        dictionary[key] = [dictionary[key], value]

# %% [markdown]
# ### 3. Formatting the SOR Regulations & Updating the DF Body Column

# %%
#Obtain the list of regulations only from the working directory
list_regs = []
files = [f for f in os.listdir('.') if os.path.isfile(f)]

for file in files:
    if file[-3:] == 'xml':
        list_regs.append(file)

# %%
#Checking the number of regulations
print (len(list_regs))
print (len(df))
# Out:
# 3199
# 3199

# %%
#Final list of each regulation's formatted body text to append to the dataframe
list_body_final = []
list_exceptions = []

for reg in list_regs:
    #Create the master dictionary for each regulation 
    doc = etree.parse(reg)
    doc_dict = make_dict_from_tree(doc.getroot())
    
    #Create the nested list for each regulation's label and associated text 
    ###Structure for one regulation --> [[Label: X, [phrase1, phrase2, phrase3]],[Label: Y, [Phrase5, Phrase6]]]
    list_reg_labeled_body = []  
    
    #The following code will execute assuming the reg follows the conventional structure...track the exceptions
    try:
        #Iterate through each part of a regulation's body (i.e. the labels such as label 1, label 2 etc.)
        Parts = len(doc_dict['Regulation']['Body']['Section'])

        for i in range(0,Parts):
            #Identify the title (e.g.number) of each section in the regulation body
            label_number = str(doc_dict['Regulation']['Body']['Section'][i]["Label"])
            label_tag = "Label: " + label_clean(label_number)

            #Determine all the contents associated with the label, removing the label key
            label_text = doc_dict['Regulation']['Body']['Section'][i].copy()
            del label_text['Label']

            #Format the text for each label, removing remains of xml tags and dictionary formatting
            label_text = body_clean(str(label_text))
            label_text = label_text.split("'")
            list_label_text = []

            for phrase in label_text:
                if len(phrase) > 2:
                    list_label_text.append(phrase)

            #Create the nested pair of label_tag + label_text --> [Label: X, [phrase1, phrase2, phrase3]]
            label_pair = []
            label_pair.append(label_tag)
            label_pair.append(list_label_text)

            #Append all the nested lists for each individual regulation
            list_reg_labeled_body.append(label_pair)   

        #Append each regulations final label-text nested list for adding to the df
        list_body_final.append(list_reg_labeled_body)
        
    except:
        list_body_final.append("")
        list_exceptions.append(reg)

# %%
#Checking the length of the outputs
print (len(list_body_final))
print (len(list_exceptions))
# Out:
# 3199
# 77

# %%
#Updating the main df 'Body' column
df["Body"] = list_body_final

# %% [markdown]
# ### 4. Counting the Outdated Item Occurances

# %%
#List of formatted body text 
list_body = df['Body']

# %%
for tech in list_outdated_tech:  
    outdated_tech_count = []
    
    for body in list_body:
        #use the '\\b' word boundary to only return exact matches
        n = re.findall('\\b' + tech + '\\b', str(body).lower())
        outdated_tech_count.append(len(n))
        
    df[tech] = outdated_tech_count
df['Outdated_Tech_Total'] = df[list_outdated_tech].sum(axis=1)

# %%
for process in list_outdated_process:
    outdated_process_count = []
    
    for body in list_body:
        #use the '\\b' word boundary to only return exact matches
        n = re.findall('\\b' + process + '\\b', str(body).lower())
        outdated_process_count.append(len(n))
        
    df[process] = outdated_process_count

df['Outdated_Process_Total'] = df[list_outdated_process].sum(axis=1)

# %%
#Checking the output - regulations with outdated tech (any)
df[df['Instrumentation_Num']=='SOR/2000-187']
# Out:
#     Instrumentation_Num Registration_Date Consolidation_Date Last_Mod_Date  \
# 586        SOR/2000-187          5/4/2000         06/21/2018     12/1/2005
#
#                                     Enabling_Authority Short_Title  \
# 586  ['AGRICULTURE AND AGRI-FOOD ADMINISTRATIVE MON...         NaN
#
#                                             Long_Title Reg_Maker  \
# 586  Agriculture and Agri-Food Administrative Monet...       NaN
#
#     Reg_Order_Num Reg_Order_Maker_Date Schedule  \
# 586           NaN                  NaN      NaN
#
#                                                  Order  \
# 586  <Provision format-ref="indent-0-0" language-al...
#
#                                                   Body  paper  print  mail  \
# 586  [[Label: 1, [The following definitions apply i...      0      0     9
#
#      fax  pen  pencil  ink  carbon copy  hard copy  original copy  on site  \
# 586    8    0       0    0            0          1              0        0
#
#      on-site  file  filing  Outdated_Tech_Total  written  write  wrote  \
# 586        0     0       0                   18        1      0      0
#
#      physical  proof  signed  in person  in-person  notary  submission  \
# 586         0      0       0          0          0       0           0
#
#      non-electronic  non electronic  document (excluding electronic)  \
# 586               0               0                                0
#
#      excluding electronic  signature  Outdated_Process_Total
# 586                     0          0                       1

# %% [markdown]
# ### 5. Extracting the Outdated Phrases & Locations

# %% [markdown]
# ##### Outdated Tech

# %%
#Final lists to be appended to the df --> {'tech':'labelX':['phrase1'],['phrase2']}
outdated_phrases_tech = []

#looking at each regulation individually and checking for all outdated tech one at a time 
for body in list_body:
    
    #Format for each regulation will be a nested dictionary
    ## {tech1:{label1:[phrase1, phrase2], label2:[phrase3]}, tech2:{label6:[phrase5,phrase6]}, etc..}
    master_dict_tech = {}
    
    for tech in list_outdated_tech:
    #Iterate through each regulations body 'label' and the list of text 'phrases' for each 'label'
        for label in range(0,len(body)):
            label_name = str(body[label][0])
            label_phrase_dict = {}
            
            for phrase in body[label][1]:
                #check if the outdated item exists (exact match only)
                if len(re.findall('\\b' + tech + '\\b', str(phrase).lower())) > 0:
                    #Use the pre defined dictionary helper function, checks if key already exists
                    set_key(label_phrase_dict, label_name, phrase)
            
            #Only add to the master dictionary if outdated tech was found (not empty dictionary)
            if bool(label_phrase_dict):
                set_key(master_dict_tech, tech, label_phrase_dict)
        
    #Append the final master dict to the list
    outdated_phrases_tech.append(master_dict_tech)
    
#update the final dataframe 
df['Outdated_Phrases_Tech'] = outdated_phrases_tech

# %% [markdown]
# ##### Outdated Process

# %%
#Final lists to be appended to the df --> {'tech':'labelX':['phrase1'],['phrase2']}
outdated_phrases_process = []

#looking at each regulation individually and checking for all outdated tech one at a time 
for body in list_body:
    
    #Format for each regulation will be a nested dictionary
    ## {tech1:{label1:[phrase1, phrase2], label2:[phrase3]}, tech2:{label6:[phrase5,phrase6]}, etc..}
    master_dict_process = {}

    for process in list_outdated_process:
    #Iterate through each regulations body 'label' and the list of text 'phrases' for each 'label'
        for label in range(0,len(body)):
            label_name = str(body[label][0])
            label_phrase_dict = {}
            
            for phrase in body[label][1]:
                #check if the outdated item exists (exact match only)
                if len(re.findall('\\b' + process + '\\b', str(phrase).lower())) > 0:
                    #Use the pre defined dictionary helper function, checks if key already exists
                    set_key(label_phrase_dict, label_name, phrase)
            
            #Only add to the master dictionary if outdated tech was found (not empty dictionary)
            if bool(label_phrase_dict):
                set_key(master_dict_process, process, label_phrase_dict)
        
    #Append the final master dict to the list
    outdated_phrases_process.append(master_dict_process)
        
#update the final dataframe 
df['Outdated_Phrases_Process'] = outdated_phrases_process

# %% [markdown]
# ##### Exporting to Excel

# %%
df['Outdated_Phrases_Process'][17]
# Out:
# {'written': {'Label: 7': 'Every licensee shall obtain from each nuclear energy worker who is informed of the matters referred to in paragraphs (1)(a) and (b) and subsection (2) a written acknowledgement that the worker has received the information.'}}

# %%
#Export the df to xlms 
df.to_excel('AI_Reg_Flat_Table_V3_Final.xlsx')

# %% [markdown]
# ### 6. Analyzing the Outputs

# %%
df['Body'][0]
# Out:
# [['Label: 1',
#   ['The definitions in this section apply in these Regulations.',
#    'Definition',
#    'XRefExternal',
#    'Public Service Superannuation Act',
#    'DefinedTermFr',
#    'Loi',
#    'DefinedTermEn',
#    'Act',
#    'DefinedTermFr',
#    'nouvel employeur',
#    'DefinedTermEn',
#    'new employer']],
#  ['Label: 2',
#   ['Subsection',
#    'XRefExternal',
#    'Divestiture of Service Transitional Coverage Regulations',
#    'Label',
#    '(1)',
#    'These Regulations do not apply to a person who subsequently becomes re-employed by the new employer.',
#    'Label',
#    '(2)',
#    'Sections 4 to 9 do not apply to a person who has exercised an option under subsection 3(2).',
#    'Label',
#    '(3)',
#    'HistoricalNote',
#    'SOR/2016-203, s. 74(E).']],
#  ['Label: 3',
#   ['Subsection',
#    'Sections 12, 13 and 13.01 of the Act only apply to a person on and after the date on which that person ceases to be employed by the new employer.',
#    'Label',
#    '(1)',
#    'Despite subsection (1), where, on or after January 1, 2000, a person would be eligible, were it not for these Regulations, to exercise an option under subsection 12(3) or section 13.01 of the Act, the person may exercise such an option no later than one year after the date on which the person ceases to be employed in the public service and becomes employed by the new employer.',
#    'Label',
#    '(2)',
#    'XRefExternal',
#    'Public Service Superannuation Regulations',
#    'Label',
#    '(3)',
#    'HistoricalNote',
#    'SOR/2016-203, s. 74(E).']],
#  ['Label: 4',
#   ['For the purposes of subsection 12(8) of the Act, the survivor and children of a person who dies while employed by the new employer are entitled to a death benefit equal to a return of contributions.']],
#  ['Label: 5',
#   ['For the purposes of subsection 13(3) of the Act, the survivor and children of a person who dies while employed by the new employer are entitled to an allowance as described in paragraphs 12(4)(a) and (b) of the Act, subject to the limitations set out in subsections 12(4) and (5) of the Act.']],
#  ['Label: 6',
#   ['For the purposes of subsection 26(2) of the Act, a child who was born to or adopted by a person or became the stepchild of the person during the period that begins on the date on which the person ceases to be employed in the public service and that ends on the date on which that person ceases to be employed by the new employer is entitled to an allowance under Part I of the Act.',
#    'HistoricalNote',
#    'SOR/2016-203, s. 74(E).']],
#  ['Label: 7',
#   ['For the purposes of subsection 10(5) of the Act, the one year period referred to in paragraph 10(5)(a) of the Act shall begin on the date on which the person ceases to be employed by the new employer.']],
#  ['Label: 8',
#   ['For the purposes of sections 12 and 13 of the Act, pensionable service includes the period of service with the new employer that begins on the date on which the person ceases to be employed in the public service and that ends on the date on which the person ceases to be employed by the new employer.',
#    'HistoricalNote',
#    'SOR/2016-203, s. 74(E).']],
#  ['Label: 9',
#   ['For the purposes of sections 12 and 13 of the Act, the age of a person when the person ceases to be employed in the public service is the age of the person on the day on which that person ceases to be employed by the new employer.',
#    'HistoricalNote',
#    'SOR/2016-203, s. 74(E).']],
#  ['Label: 9.1',
#   ['A contributor to whom these Regulations apply is considered to be a Group 1 contributor.',
#    'HistoricalNote',
#    'SOR/2016-203, s. 73.']],
#  ['Label: 10', ['These Regulations come into force on January 1, 2000.']]]

# %%
df['Outdated_Phrases_Tech'][15].keys()
# Out:
# ['mail', 'fax', 'hard copy']

# %%
for tech in list_outdated_tech:
    print (tech + " : " + str(len(df[df[tech]>0])))
# Out:
# paper : 136
# print : 99
# mail : 316
# fax : 80
# pen : 731
# pencil : 5
# ink : 65
# carbon copy : 0
# hard copy : 4
# original copy : 5
# proof : 94
# on site : 38
# file : 238
# filing : 100
# submit : 360
# submission(non-electronic) : 0
# non-electronic : 2
# document (excluding electronic) : 0
# excluding electronic : 0

# %%
for process in list_outdated_process:
    print (process + " : " + str(len(df[df[process]>0])))
# Out:
# written : 380
# write : 28
# wrote : 0
# physical : 129
# proof : 94
# signed : 417
# in person : 70
# in-person : 0
# original copy : 5
# notary : 16
# submit : 360
# submission(non-electronic) : 0
# non-electronic : 2
# document (excluding electronic) : 0
# excluding electronic : 0
# written : 380
# signature : 69

# %%
list_regs
# Out:
# ['SOR-2000-1.xml',
#  'SOR-2000-100.xml',
#  'SOR-2000-107.xml',
#  'SOR-2000-108.xml',
#  'SOR-2000-111.xml',
#  'SOR-2000-112.xml',
#  'SOR-2000-113.xml',
#  'SOR-2000-131.xml',
#  'SOR-2000-132.xml',
#  'SOR-2000-14.xml',
#  'SOR-2000-141.xml',
#  'SOR-2000-142.xml',
#  'SOR-2000-143.xml',
#  'SOR-2000-177.xml',
#  'SOR-2000-181.xml',
#  'SOR-2000-187.xml',
#  'SOR-2000-202.xml',
#  'SOR-2000-203.xml',
#  'SOR-2000-204.xml',
#  'SOR-2000-205.xml',
#  'SOR-2000-206.xml',
#  'SOR-2000-207.xml',
#  'SOR-2000-208.xml',
#  'SOR-2000-209.xml',
#  'SOR-2000-210.xml',
#  'SOR-2000-211.xml',
#  'SOR-2000-212.xml',
#  'SOR-2000-214.xml',
#  'SOR-2000-217.xml',
#  'SOR-2000-228.xml',
#  'SOR-2000-230.xml',
#  'SOR-2000-233.xml',
#  'SOR-2000-253.xml',
#  'SOR-2000-260.xml',
#  'SOR-2000-265.xml',
#  'SOR-2000-272.xml',
#  'SOR-2000-273.xml',
#  'SOR-2000-277.xml',
#  'SOR-2000-283.xml',
#  'SOR-2000-294.xml',
#  'SOR-2000-300.xml',
#  'SOR-2000-303.xml',
#  'SOR-2000-306.xml',
#  'SOR-2000-324.xml',
#  'SOR-2000-375.xml',
#  'SOR-2000-376.xml',
#  'SOR-2000-387.xml',
#  'SOR-2000-418.xml',
#  'SOR-2000-42.xml',
#  'SOR-2000-43.xml',
#  'SOR-2000-52.xml',
#  'SOR-2000-53.xml',
#  'SOR-2000-54.xml',
#  'SOR-2000-55.xml',
#  'SOR-2000-60.xml',
#  'SOR-2000-66.xml',
#  'SOR-2000-69.xml',
#  'SOR-2000-7.xml',
#  'SOR-2000-70.xml',
#  'SOR-2000-71.xml',
#  'SOR-2000-77.xml',
#  'SOR-2000-92.xml',
#  'SOR-2001-101.xml',
#  'SOR-2001-102.xml',
#  'SOR-2001-103.xml',
#  'SOR-2001-104.xml',
#  'SOR-2001-115.xml',
#  'SOR-2001-132.xml',
#  'SOR-2001-154.xml',
#  'SOR-2001-161.xml',
#  'SOR-2001-170.xml',
#  'SOR-2001-171.xml',
#  'SOR-2001-177.xml',
#  'SOR-2001-182.xml',
#  'SOR-2001-205.xml',
#  'SOR-2001-206.xml',
#  'SOR-2001-207.xml',
#  'SOR-2001-211.xml',
#  'SOR-2001-219.xml',
#  'SOR-2001-220.xml',
#  'SOR-2001-226.xml',
#  'SOR-2001-227.xml',
#  'SOR-2001-248.xml',
#  'SOR-2001-251.xml',
#  'SOR-2001-258.xml',
#  'SOR-2001-261.xml',
#  'SOR-2001-269.xml',
#  'SOR-2001-275.xml',
#  'SOR-2001-276.xml',
#  'SOR-2001-281.xml',
#  'SOR-2001-282.xml',
#  'SOR-2001-283.xml',
#  'SOR-2001-286.xml',
#  'SOR-2001-296.xml',
#  'SOR-2001-297.xml',
#  'SOR-2001-317.xml',
#  'SOR-2001-32.xml',
#  'SOR-2001-344.xml',
#  'SOR-2001-345.xml',
#  'SOR-2001-360.xml',
#  'SOR-2001-363.xml',
#  'SOR-2001-364.xml',
#  'SOR-2001-365.xml',
#  'SOR-2001-366.xml',
#  'SOR-2001-368.xml',
#  'SOR-2001-37.xml',
#  'SOR-2001-370.xml',
#  'SOR-2001-371.xml',
#  'SOR-2001-372.xml',
#  'SOR-2001-373.xml',
#  'SOR-2001-374.xml',
#  'SOR-2001-375.xml',
#  'SOR-2001-376.xml',
#  'SOR-2001-377.xml',
#  'SOR-2001-378.xml',
#  'SOR-2001-379.xml',
#  'SOR-2001-380.xml',
#  'SOR-2001-381.xml',
#  'SOR-2001-382.xml',
#  'SOR-2001-383.xml',
#  'SOR-2001-384.xml',
#  'SOR-2001-385.xml',
#  'SOR-2001-386.xml',
#  'SOR-2001-387.xml',
#  'SOR-2001-388.xml',
#  'SOR-2001-389.xml',
#  'SOR-2001-390.xml',
#  'SOR-2001-391.xml',
#  'SOR-2001-392.xml',
#  'SOR-2001-393.xml',
#  'SOR-2001-394.xml',
#  'SOR-2001-395.xml',
#  'SOR-2001-396.xml',
#  'SOR-2001-397.xml',
#  'SOR-2001-398.xml',
#  'SOR-2001-399.xml',
#  'SOR-2001-400.xml',
#  'SOR-2001-401.xml',
#  'SOR-2001-402.xml',
#  'SOR-2001-403.xml',
#  'SOR-2001-404.xml',
#  'SOR-2001-405.xml',
#  'SOR-2001-406.xml',
#  'SOR-2001-407.xml',
#  'SOR-2001-408.xml',
#  'SOR-2001-409.xml',
#  'SOR-2001-410.xml',
#  'SOR-2001-411.xml',
#  'SOR-2001-412.xml',
#  'SOR-2001-413.xml',
#  'SOR-2001-414.xml',
#  'SOR-2001-418.xml',
#  'SOR-2001-420.xml',
#  'SOR-2001-424.xml',
#  'SOR-2001-426.xml',
#  'SOR-2001-427.xml',
#  'SOR-2001-428.xml',
#  'SOR-2001-429.xml',
#  'SOR-2001-430.xml',
#  'SOR-2001-431.xml',
#  'SOR-2001-432.xml',
#  'SOR-2001-433.xml',
#  'SOR-2001-434.xml',
#  'SOR-2001-435.xml',
#  'SOR-2001-436.xml',
#  'SOR-2001-437.xml',
#  'SOR-2001-451.xml',
#  'SOR-2001-471.xml',
#  'SOR-2001-472.xml',
#  'SOR-2001-473.xml',
#  'SOR-2001-474.xml',
#  'SOR-2001-475.xml',
#  'SOR-2001-476.xml',
#  'SOR-2001-477.xml',
#  'SOR-2001-478.xml',
#  'SOR-2001-480.xml',
#  'SOR-2001-484.xml',
#  'SOR-2001-493.xml',
#  'SOR-2001-496.xml',
#  'SOR-2001-512.xml',
#  'SOR-2001-518.xml',
#  'SOR-2001-520.xml',
#  'SOR-2001-527.xml',
#  'SOR-2001-532.xml',
#  'SOR-2001-55.xml',
#  'SOR-2001-56.xml',
#  'SOR-2001-57.xml',
#  'SOR-2001-58.xml',
#  'SOR-2001-59.xml',
#  'SOR-2001-6.xml',
#  'SOR-2001-65.xml',
#  'SOR-2001-66.xml',
#  'SOR-2001-7.xml',
#  'SOR-2001-8.xml',
#  'SOR-2001-84.xml',
#  'SOR-2002-101.xml',
#  'SOR-2002-102.xml',
#  'SOR-2002-103.xml',
#  'SOR-2002-104.xml',
#  'SOR-2002-105.xml',
#  'SOR-2002-106.xml',
#  'SOR-2002-109.xml',
#  'SOR-2002-11.xml',
#  'SOR-2002-132.xml',
#  'SOR-2002-133.xml',
#  'SOR-2002-138.xml',
#  'SOR-2002-142.xml',
#  'SOR-2002-145.xml',
#  'SOR-2002-146.xml',
#  'SOR-2002-147.xml',
#  'SOR-2002-148.xml',
#  'SOR-2002-156.xml',
#  'SOR-2002-16.xml',
#  'SOR-2002-162.xml',
#  'SOR-2002-163.xml',
#  'SOR-2002-164.xml',
#  'SOR-2002-172.xml',
#  'SOR-2002-180.xml',
#  'SOR-2002-184.xml',
#  'SOR-2002-195.xml',
#  'SOR-2002-196.xml',
#  'SOR-2002-215.xml',
#  'SOR-2002-216.xml',
#  'SOR-2002-22.xml',
#  'SOR-2002-222.xml',
#  'SOR-2002-223.xml',
#  'SOR-2002-224.xml',
#  'SOR-2002-227.xml',
#  'SOR-2002-228.xml',
#  'SOR-2002-229.xml',
#  'SOR-2002-230.xml',
#  'SOR-2002-231.xml',
#  'SOR-2002-241.xml',
#  'SOR-2002-25.xml',
#  'SOR-2002-253.xml',
#  'SOR-2002-254.xml',
#  'SOR-2002-259.xml',
#  'SOR-2002-260.xml',
#  'SOR-2002-262.xml',
#  'SOR-2002-263.xml',
#  'SOR-2002-264.xml',
#  'SOR-2002-265.xml',
#  'SOR-2002-266.xml',
#  'SOR-2002-284.xml',
#  'SOR-2002-301.xml',
#  'SOR-2002-302.xml',
#  'SOR-2002-303.xml',
#  'SOR-2002-307.xml',
#  'SOR-2002-316.xml',
#  'SOR-2002-317.xml',
#  'SOR-2002-336.xml',
#  'SOR-2002-337.xml',
#  'SOR-2002-339.xml',
#  'SOR-2002-34.xml',
#  'SOR-2002-348.xml',
#  'SOR-2002-35.xml',
#  'SOR-2002-351.xml',
#  'SOR-2002-359.xml',
#  'SOR-2002-36.xml',
#  'SOR-2002-371.xml',
#  'SOR-2002-373.xml',
#  'SOR-2002-374.xml',
#  'SOR-2002-39.xml',
#  'SOR-2002-395.xml',
#  'SOR-2002-396.xml',
#  'SOR-2002-397.xml',
#  'SOR-2002-398.xml',
#  'SOR-2002-399.xml',
#  'SOR-2002-4.xml',
#  'SOR-2002-400.xml',
#  'SOR-2002-401.xml',
#  'SOR-2002-412.xml',
#  'SOR-2002-414.xml',
#  'SOR-2002-415.xml',
#  'SOR-2002-416.xml',
#  'SOR-2002-420.xml',
#  'SOR-2002-421.xml',
#  'SOR-2002-422.xml',
#  'SOR-2002-423.xml',
#  'SOR-2002-445.xml',
#  'SOR-2002-450.xml',
#  'SOR-2002-47.xml',
#  'SOR-2002-48.xml',
#  'SOR-2002-54.xml',
#  'SOR-2002-63.xml',
#  'SOR-2002-65.xml',
#  'SOR-2002-66.xml',
#  'SOR-2002-75.xml',
#  'SOR-2002-76.xml',
#  'SOR-2003-105.xml',
#  'SOR-2003-115.xml',
#  'SOR-2003-124.xml',
#  'SOR-2003-125.xml',
#  'SOR-2003-15.xml',
#  'SOR-2003-174.xml',
#  'SOR-2003-175.xml',
#  'SOR-2003-180.xml',
#  'SOR-2003-181.xml',
#  'SOR-2003-184.xml',
#  'SOR-2003-185.xml',
#  'SOR-2003-186.xml',
#  'SOR-2003-192.xml',
#  'SOR-2003-196.xml',
#  'SOR-2003-2.xml',
#  'SOR-2003-200.xml',
#  'SOR-2003-201.xml',
#  'SOR-2003-202.xml',
#  'SOR-2003-203.xml',
#  'SOR-2003-204.xml',
#  'SOR-2003-205.xml',
#  'SOR-2003-206.xml',
#  'SOR-2003-207.xml',
#  'SOR-2003-212.xml',
#  'SOR-2003-215.xml',
#  'SOR-2003-219.xml',
#  'SOR-2003-225.xml',
#  'SOR-2003-242.xml',
#  'SOR-2003-243.xml',
#  'SOR-2003-244.xml',
#  'SOR-2003-245.xml',
#  'SOR-2003-261.xml',
#  'SOR-2003-267.xml',
#  'SOR-2003-274.xml',
#  'SOR-2003-28.xml',
#  'SOR-2003-283.xml',
#  'SOR-2003-286.xml',
#  'SOR-2003-288.xml',
#  'SOR-2003-289.xml',
#  'SOR-2003-293.xml',
#  'SOR-2003-297.xml',
#  'SOR-2003-298.xml',
#  'SOR-2003-299.xml',
#  'SOR-2003-30.xml',
#  'SOR-2003-300.xml',
#  'SOR-2003-301.xml',
#  'SOR-2003-307.xml',
#  'SOR-2003-309.xml',
#  'SOR-2003-31.xml',
#  'SOR-2003-310.xml',
#  'SOR-2003-312.xml',
#  'SOR-2003-313.xml',
#  'SOR-2003-323.xml',
#  'SOR-2003-343.xml',
#  'SOR-2003-346.xml',
#  'SOR-2003-347.xml',
#  'SOR-2003-355.xml',
#  'SOR-2003-357.xml',
#  'SOR-2003-363.xml',
#  'SOR-2003-374.xml',
#  'SOR-2003-39.xml',
#  'SOR-2003-429.xml',
#  'SOR-2003-430.xml',
#  'SOR-2003-51.xml',
#  'SOR-2003-60.xml',
#  'SOR-2003-61.xml',
#  'SOR-2003-62.xml',
#  'SOR-2003-63.xml',
#  'SOR-2003-64.xml',
#  'SOR-2003-65.xml',
#  'SOR-2003-66.xml',
#  'SOR-2003-67.xml',
#  'SOR-2003-68.xml',
#  'SOR-2003-69.xml',
#  'SOR-2003-72.xml',
#  'SOR-2003-73.xml',
#  'SOR-2003-75.xml',
#  'SOR-2003-78.xml',
#  'SOR-2003-79.xml',
#  'SOR-2003-87.xml',
#  'SOR-2004-102.xml',
#  'SOR-2004-105.xml',
#  'SOR-2004-107.xml',
#  'SOR-2004-112.xml',
#  'SOR-2004-113.xml',
#  'SOR-2004-129.xml',
#  'SOR-2004-130.xml',
#  'SOR-2004-136.xml',
#  'SOR-2004-137.xml',
#  'SOR-2004-144.xml',
#  'SOR-2004-15.xml',
#  'SOR-2004-150.xml',
#  'SOR-2004-155.xml',
#  'SOR-2004-156.xml',
#  'SOR-2004-174.xml',
#  'SOR-2004-187.xml',
#  'SOR-2004-197.xml',
#  'SOR-2004-199.xml',
#  'SOR-2004-211.xml',
#  'SOR-2004-212.xml',
#  'SOR-2004-219.xml',
#  'SOR-2004-220.xml',
#  'SOR-2004-221.xml',
#  'SOR-2004-222.xml',
#  'SOR-2004-239.xml',
#  'SOR-2004-257.xml',
#  'SOR-2004-264.xml',
#  'SOR-2004-275.xml',
#  'SOR-2004-284.xml',
#  'SOR-2004-293.xml',
#  'SOR-2004-301.xml',
#  'SOR-2004-304.xml',
#  'SOR-2004-305.xml',
#  'SOR-2004-306.xml',
#  'SOR-2004-307.xml',
#  'SOR-2004-308.xml',
#  'SOR-2004-310.xml',
#  'SOR-2004-321.xml',
#  'SOR-2004-322.xml',
#  'SOR-2004-53.xml',
#  'SOR-2004-62.xml',
#  'SOR-2004-69.xml',
#  'SOR-2004-8.xml',
#  'SOR-2004-86.xml',
#  'SOR-2004-93.xml',
#  'SOR-2004-96.xml',
#  'SOR-2004-99.xml',
#  'SOR-2005-1.xml',
#  'SOR-2005-10.xml',
#  'SOR-2005-103.xml',
#  'SOR-2005-106.xml',
#  'SOR-2005-109.xml',
#  'SOR-2005-112.xml',
#  'SOR-2005-120.xml',
#  'SOR-2005-127.xml',
#  'SOR-2005-131.xml',
#  'SOR-2005-132.xml',
#  'SOR-2005-134.xml',
#  'SOR-2005-138.xml',
#  'SOR-2005-143.xml',
#  'SOR-2005-149.xml',
#  'SOR-2005-151.xml',
#  'SOR-2005-16.xml',
#  'SOR-2005-178.xml',
#  'SOR-2005-180.xml',
#  'SOR-2005-2.xml',
#  'SOR-2005-200.xml',
#  'SOR-2005-204.xml',
#  'SOR-2005-205.xml',
#  'SOR-2005-22.xml',
#  'SOR-2005-220.xml',
#  'SOR-2005-226.xml',
#  'SOR-2005-23.xml',
#  'SOR-2005-232.xml',
#  'SOR-2005-247.xml',
#  'SOR-2005-248.xml',
#  'SOR-2005-256.xml',
#  'SOR-2005-257.xml',
#  'SOR-2005-263.xml',
#  'SOR-2005-267.xml',
#  'SOR-2005-280.xml',
#  'SOR-2005-291.xml',
#  'SOR-2005-293.xml',
#  'SOR-2005-294.xml',
#  'SOR-2005-295.xml',
#  'SOR-2005-30.xml',
#  'SOR-2005-309.xml',
#  'SOR-2005-311.xml',
#  'SOR-2005-313.xml',
#  'SOR-2005-32.xml',
#  'SOR-2005-328.xml',
#  'SOR-2005-334.xml',
#  'SOR-2005-338.xml',
#  'SOR-2005-346.xml',
#  'SOR-2005-347.xml',
#  'SOR-2005-35.xml',
#  'SOR-2005-352.xml',
#  'SOR-2005-353.xml',
#  'SOR-2005-37.xml',
#  'SOR-2005-373.xml',
#  'SOR-2005-375.xml',
#  'SOR-2005-376.xml',
#  'SOR-2005-377.xml',
#  'SOR-2005-379.xml',
#  'SOR-2005-380.xml',
#  'SOR-2005-392.xml',
#  'SOR-2005-399.xml',
#  'SOR-2005-404.xml',
#  'SOR-2005-41.xml',
#  'SOR-2005-43.xml',
#  'SOR-2005-59.xml',
#  'SOR-2005-6.xml',
#  'SOR-2005-60.xml',
#  'SOR-2005-62.xml',
#  'SOR-2005-73.xml',
#  'SOR-2005-78.xml',
#  'SOR-2005-79.xml',
#  'SOR-2005-99.xml',
#  'SOR-2006-102.xml',
#  'SOR-2006-104.xml',
#  'SOR-2006-114.xml',
#  'SOR-2006-115.xml',
#  'SOR-2006-124.xml',
#  'SOR-2006-129.xml',
#  'SOR-2006-137.xml',
#  'SOR-2006-139.xml',
#  'SOR-2006-15.xml',
#  'SOR-2006-168.xml',
#  'SOR-2006-190.xml',
#  'SOR-2006-195.xml',
#  'SOR-2006-229.xml',
#  'SOR-2006-230.xml',
#  'SOR-2006-236.xml',
#  'SOR-2006-243.xml',
#  'SOR-2006-244.xml',
#  'SOR-2006-245.xml',
#  'SOR-2006-246.xml',
#  'SOR-2006-247.xml',
#  'SOR-2006-252.xml',
#  'SOR-2006-254.xml',
#  'SOR-2006-260.xml',
#  'SOR-2006-261.xml',
#  'SOR-2006-275.xml',
#  'SOR-2006-287.xml',
#  'SOR-2006-288.xml',
#  'SOR-2006-298.xml',
#  'SOR-2006-299.xml',
#  'SOR-2006-300.xml',
#  'SOR-2006-301.xml',
#  'SOR-2006-302.xml',
#  'SOR-2006-303.xml',
#  'SOR-2006-304.xml',
#  'SOR-2006-305.xml',
#  'SOR-2006-306.xml',
#  'SOR-2006-307.xml',
#  'SOR-2006-308.xml',
#  'SOR-2006-309.xml',
#  'SOR-2006-310.xml',
#  'SOR-2006-311.xml',
#  'SOR-2006-312.xml',
#  'SOR-2006-313.xml',
#  'SOR-2006-314.xml',
#  'SOR-2006-315.xml',
#  'SOR-2006-316.xml',
#  'SOR-2006-317.xml',
#  'SOR-2006-318.xml',
#  'SOR-2006-319.xml',
#  'SOR-2006-320.xml',
#  'SOR-2006-321.xml',
#  'SOR-2006-330.xml',
#  'SOR-2006-337.xml',
#  'SOR-2006-338.xml',
#  'SOR-2006-347.xml',
#  'SOR-2006-354.xml',
#  'SOR-2006-355.xml',
#  'SOR-2006-36.xml',
#  'SOR-2006-43.xml',
#  'SOR-2006-50.xml',
#  'SOR-2006-6.xml',
#  'SOR-2006-78.xml',
#  'SOR-2006-92.xml',
#  'SOR-2006-95.xml',
#  'SOR-2007-108.xml',
#  'SOR-2007-115.xml',
#  'SOR-2007-118.xml',
#  'SOR-2007-121.xml',
#  'SOR-2007-123.xml',
#  'SOR-2007-125.xml',
#  'SOR-2007-126.xml',
#  'SOR-2007-127.xml',
#  'SOR-2007-128.xml',
#  'SOR-2007-134.xml',
#  'SOR-2007-135.xml',
#  'SOR-2007-137.xml',
#  'SOR-2007-15.xml',
#  'SOR-2007-151.xml',
#  'SOR-2007-16.xml',
#  'SOR-2007-160.xml',
#  'SOR-2007-165.xml',
#  'SOR-2007-166.xml',
#  'SOR-2007-17.xml',
#  'SOR-2007-173.xml',
#  'SOR-2007-174.xml',
#  'SOR-2007-193.xml',
#  'SOR-2007-194.xml',
#  'SOR-2007-201.xml',
#  'SOR-2007-204.xml',
#  'SOR-2007-231.xml',
#  'SOR-2007-232.xml',
#  'SOR-2007-237.xml',
#  'SOR-2007-239.xml',
#  'SOR-2007-240.xml',
#  'SOR-2007-241.xml',
#  'SOR-2007-242.xml',
#  'SOR-2007-243.xml',
#  'SOR-2007-244.xml',
#  'SOR-2007-245.xml',
#  'SOR-2007-25.xml',
#  'SOR-2007-252.xml',
#  'SOR-2007-255.xml',
#  'SOR-2007-256.xml',
#  'SOR-2007-257.xml',
#  'SOR-2007-258.xml',
#  'SOR-2007-260.xml',
#  'SOR-2007-267.xml',
#  'SOR-2007-272.xml',
#  'SOR-2007-277.xml',
#  'SOR-2007-282.xml',
#  'SOR-2007-285.xml',
#  'SOR-2007-286.xml',
#  'SOR-2007-292.xml',
#  'SOR-2007-294.xml',
#  'SOR-2007-299.xml',
#  'SOR-2007-303.xml',
#  'SOR-2007-305.xml',
#  'SOR-2007-31.xml',
#  'SOR-2007-32.xml',
#  'SOR-2007-44.xml',
#  'SOR-2007-49.xml',
#  'SOR-2007-63.xml',
#  'SOR-2007-66.xml',
#  'SOR-2007-67.xml',
#  'SOR-2007-71.xml',
#  'SOR-2007-77.xml',
#  'SOR-2007-79.xml',
#  'SOR-2007-82.xml',
#  'SOR-2007-86.xml',
#  'SOR-2007-99.xml',
#  'SOR-2008-102.xml',
#  'SOR-2008-109.xml',
#  'SOR-2008-115.xml',
#  'SOR-2008-116.xml',
#  'SOR-2008-117.xml',
#  'SOR-2008-120.xml',
#  'SOR-2008-121.xml',
#  'SOR-2008-124.xml',
#  'SOR-2008-138.xml',
#  'SOR-2008-141.xml',
#  'SOR-2008-143.xml',
#  'SOR-2008-156.xml',
#  'SOR-2008-158.xml',
#  'SOR-2008-163.xml',
#  'SOR-2008-167.xml',
#  'SOR-2008-178.xml',
#  'SOR-2008-180.xml',
#  'SOR-2008-185.xml',
#  'SOR-2008-186.xml',
#  'SOR-2008-196.xml',
#  'SOR-2008-197.xml',
#  'SOR-2008-208.xml',
#  'SOR-2008-209.xml',
#  'SOR-2008-210.xml',
#  'SOR-2008-212.xml',
#  'SOR-2008-218.xml',
#  'SOR-2008-22.xml',
#  'SOR-2008-222.xml',
#  'SOR-2008-231.xml',
#  'SOR-2008-236.xml',
#  'SOR-2008-244.xml',
#  'SOR-2008-247.xml',
#  'SOR-2008-248.xml',
#  'SOR-2008-249.xml',
#  'SOR-2008-252.xml',
#  'SOR-2008-273.xml',
#  'SOR-2008-275.xml',
#  'SOR-2008-292.xml',
#  'SOR-2008-306.xml',
#  'SOR-2008-319.xml',
#  'SOR-2008-45.xml',
#  'SOR-2008-47.xml',
#  'SOR-2008-48.xml',
#  'SOR-2008-50.xml',
#  'SOR-2008-57.xml',
#  'SOR-2008-58.xml',
#  'SOR-2008-59.xml',
#  'SOR-2008-60.xml',
#  'SOR-2008-64.xml',
#  'SOR-2008-65.xml',
#  'SOR-2008-66.xml',
#  'SOR-2008-67.xml',
#  'SOR-2008-68.xml',
#  'SOR-2008-69.xml',
#  'SOR-2008-76.xml',
#  'SOR-2008-79.xml',
#  'SOR-2008-97.xml',
#  'SOR-2009-10.xml',
#  'SOR-2009-110.xml',
#  'SOR-2009-112.xml',
#  'SOR-2009-14.xml',
#  'SOR-2009-145.xml',
#  'SOR-2009-15.xml',
#  'SOR-2009-162.xml',
#  'SOR-2009-17.xml',
#  'SOR-2009-176.xml',
#  'SOR-2009-177.xml',
#  'SOR-2009-182.xml',
#  'SOR-2009-183.xml',
#  'SOR-2009-193.xml',
#  'SOR-2009-197.xml',
#  'SOR-2009-198.xml',
#  'SOR-2009-199.xml',
#  'SOR-2009-200.xml',
#  'SOR-2009-202.xml',
#  'SOR-2009-204.xml',
#  'SOR-2009-211.xml',
#  'SOR-2009-214.xml',
#  'SOR-2009-215.xml',
#  'SOR-2009-216.xml',
#  'SOR-2009-217.xml',
#  'SOR-2009-219.xml',
#  'SOR-2009-231.xml',
#  'SOR-2009-257.xml',
#  'SOR-2009-264.xml',
#  'SOR-2009-271.xml',
#  'SOR-2009-277.xml',
#  'SOR-2009-278.xml',
#  'SOR-2009-298.xml',
#  'SOR-2009-315.xml',
#  'SOR-2009-316.xml',
#  'SOR-2009-317.xml',
#  'SOR-2009-320.xml',
#  'SOR-2009-321.xml',
#  'SOR-2009-336.xml',
#  'SOR-2009-67.xml',
#  'SOR-2009-68.xml',
#  'SOR-2009-89.xml',
#  'SOR-2009-92.xml',
#  'SOR-2010-110.xml',
#  'SOR-2010-116.xml',
#  'SOR-2010-117.xml',
#  'SOR-2010-120.xml',
#  'SOR-2010-127.xml',
#  'SOR-2010-13.xml',
#  'SOR-2010-130.xml',
#  'SOR-2010-135.xml',
#  'SOR-2010-138.xml',
#  'SOR-2010-147.xml',
#  'SOR-2010-148.xml',
#  'SOR-2010-150.xml',
#  'SOR-2010-151.xml',
#  'SOR-2010-156.xml',
#  'SOR-2010-158.xml',
#  'SOR-2010-161.xml',
#  'SOR-2010-165.xml',
#  'SOR-2010-166.xml',
#  'SOR-2010-171.xml',
#  'SOR-2010-189.xml',
#  'SOR-2010-190.xml',
#  'SOR-2010-20.xml',
#  'SOR-2010-201.xml',
#  'SOR-2010-202.xml',
#  'SOR-2010-203.xml',
#  'SOR-2010-21.xml',
#  'SOR-2010-220.xml',
#  'SOR-2010-227.xml',
#  'SOR-2010-230.xml',
#  'SOR-2010-231.xml',
#  'SOR-2010-232.xml',
#  'SOR-2010-233.xml',
#  'SOR-2010-234.xml',
#  'SOR-2010-235.xml',
#  'SOR-2010-236.xml',
#  'SOR-2010-237.xml',
#  'SOR-2010-238.xml',
#  'SOR-2010-239.xml',
#  'SOR-2010-240.xml',
#  'SOR-2010-241.xml',
#  'SOR-2010-242.xml',
#  'SOR-2010-245.xml',
#  'SOR-2010-259.xml',
#  'SOR-2010-261.xml',
#  'SOR-2010-270.xml',
#  'SOR-2010-273.xml',
#  'SOR-2010-277.xml',
#  'SOR-2010-278.xml',
#  'SOR-2010-28.xml',
#  'SOR-2010-282.xml',
#  'SOR-2010-29.xml',
#  'SOR-2010-290.xml',
#  'SOR-2010-291.xml',
#  'SOR-2010-292.xml',
#  'SOR-2010-298.xml',
#  'SOR-2010-52.xml',
#  'SOR-2010-56.xml',
#  'SOR-2010-58.xml',
#  'SOR-2010-62.xml',
#  'SOR-2010-65.xml',
#  'SOR-2010-67.xml',
#  'SOR-2010-68.xml',
#  'SOR-2010-69.xml',
#  'SOR-2010-83.xml',
#  'SOR-2010-84.xml',
#  'SOR-2010-88.xml',
#  'SOR-2010-90.xml',
#  'SOR-2010-91.xml',
#  'SOR-2010-99.xml',
#  'SOR-2011-10.xml',
#  'SOR-2011-100.xml',
#  'SOR-2011-108.xml',
#  'SOR-2011-114.xml',
#  'SOR-2011-115.xml',
#  'SOR-2011-119.xml',
#  'SOR-2011-121.xml',
#  'SOR-2011-122.xml',
#  'SOR-2011-130.xml',
#  'SOR-2011-131.xml',
#  'SOR-2011-132.xml',
#  'SOR-2011-133.xml',
#  'SOR-2011-139.xml',
#  'SOR-2011-142.xml',
#  'SOR-2011-15.xml',
#  'SOR-2011-16.xml',
#  'SOR-2011-167.xml',
#  'SOR-2011-168.xml',
#  'SOR-2011-17.xml',
#  'SOR-2011-170.xml',
#  'SOR-2011-177.xml',
#  'SOR-2011-178.xml',
#  'SOR-2011-18.xml',
#  'SOR-2011-180.xml',
#  'SOR-2011-19.xml',
#  'SOR-2011-20.xml',
#  'SOR-2011-201.xml',
#  'SOR-2011-203.xml',
#  'SOR-2011-204.xml',
#  'SOR-2011-21.xml',
#  'SOR-2011-215.xml',
#  'SOR-2011-22.xml',
#  'SOR-2011-223.xml',
#  'SOR-2011-227.xml',
#  'SOR-2011-230.xml',
#  'SOR-2011-237.xml',
#  'SOR-2011-246.xml',
#  'SOR-2011-247.xml',
#  'SOR-2011-248.xml',
#  'SOR-2011-249.xml',
#  'SOR-2011-250.xml',
#  'SOR-2011-251.xml',
#  'SOR-2011-254.xml',
#  'SOR-2011-255.xml',
#  'SOR-2011-265.xml',
#  'SOR-2011-269.xml',
#  'SOR-2011-292.xml',
#  'SOR-2011-317.xml',
#  'SOR-2011-318.xml',
#  'SOR-2011-33.xml',
#  'SOR-2011-51.xml',
#  'SOR-2011-52.xml',
#  'SOR-2011-55.xml',
#  'SOR-2011-57.xml',
#  'SOR-2011-62.xml',
#  'SOR-2011-65.xml',
#  'SOR-2011-7.xml',
#  'SOR-2011-78.xml',
#  'SOR-2011-79.xml',
#  'SOR-2011-86.xml',
#  'SOR-2011-87.xml',
#  'SOR-2011-90.xml',
#  'SOR-2011-91.xml',
#  'SOR-2011-98.xml',
#  'SOR-2011-99.xml',
#  'SOR-2012-113.xml',
#  'SOR-2012-123.xml',
#  'SOR-2012-134.xml',
#  'SOR-2012-138.xml',
#  'SOR-2012-139.xml',
#  'SOR-2012-146.xml',
#  'SOR-2012-147.xml',
#  'SOR-2012-148.xml',
#  'SOR-2012-149.xml',
#  'SOR-2012-152.xml',
#  'SOR-2012-160.xml',
#  'SOR-2012-167.xml',
#  'SOR-2012-17.xml',
#  'SOR-2012-170.xml',
#  'SOR-2012-179.xml',
#  'SOR-2012-18.xml',
#  'SOR-2012-180.xml',
#  'SOR-2012-181.xml',
#  'SOR-2012-202.xml',
#  'SOR-2012-203.xml',
#  'SOR-2012-204.xml',
#  'SOR-2012-205.xml',
#  'SOR-2012-206.xml',
#  'SOR-2012-207.xml',
#  'SOR-2012-208.xml',
#  'SOR-2012-209.xml',
#  'SOR-2012-210.xml',
#  'SOR-2012-211.xml',
#  'SOR-2012-212.xml',
#  'SOR-2012-213.xml',
#  'SOR-2012-214.xml',
#  'SOR-2012-215.xml',
#  'SOR-2012-216.xml',
#  'SOR-2012-222.xml',
#  'SOR-2012-226.xml',
#  'SOR-2012-23.xml',
#  'SOR-2012-230.xml',
#  'SOR-2012-231.xml',
#  'SOR-2012-232.xml',
#  'SOR-2012-24.xml',
#  'SOR-2012-247.xml',
#  'SOR-2012-248.xml',
#  'SOR-2012-253.xml',
#  'SOR-2012-255.xml',
#  'SOR-2012-256.xml',
#  'SOR-2012-257.xml',
#  'SOR-2012-264.xml',
#  'SOR-2012-265.xml',
#  'SOR-2012-267.xml',
#  'SOR-2012-268.xml',
#  'SOR-2012-278.xml',
#  'SOR-2012-281.xml',
#  'SOR-2012-282.xml',
#  'SOR-2012-285.xml',
#  'SOR-2012-293.xml',
#  'SOR-2012-294.xml',
#  'SOR-2012-34.xml',
#  'SOR-2012-36.xml',
#  'SOR-2012-69.xml',
#  'SOR-2012-83.xml',
#  'SOR-2012-87.xml',
#  'SOR-2012-89.xml',
#  'SOR-2012-90.xml',
#  'SOR-2012-91.xml',
#  'SOR-2012-92.xml',
#  'SOR-2012-93.xml',
#  'SOR-2012-94.xml',
#  'SOR-2012-95.xml',
#  'SOR-2012-96.xml',
#  'SOR-2012-97.xml',
#  'SOR-2012-98.xml',
#  'SOR-2013-1.xml',
#  'SOR-2013-101.xml',
#  'SOR-2013-119.xml',
#  'SOR-2013-120.xml',
#  'SOR-2013-127.xml',
#  'SOR-2013-132.xml',
#  'SOR-2013-138.xml',
#  'SOR-2013-139.xml',
#  'SOR-2013-140.xml',
#  'SOR-2013-141.xml',
#  'SOR-2013-142.xml',
#  'SOR-2013-143.xml',
#  'SOR-2013-144.xml',
#  'SOR-2013-161.xml',
#  'SOR-2013-162.xml',
#  'SOR-2013-165.xml',
#  'SOR-2013-178.xml',
#  'SOR-2013-19.xml',
#  'SOR-2013-191.xml',
#  'SOR-2013-198.xml',
#  'SOR-2013-202.xml',
#  'SOR-2013-209.xml',
#  'SOR-2013-211.xml',
#  'SOR-2013-214.xml',
#  'SOR-2013-215.xml',
#  'SOR-2013-216.xml',
#  'SOR-2013-217.xml',
#  'SOR-2013-221.xml',
#  'SOR-2013-236.xml',
#  'SOR-2013-238.xml',
#  'SOR-2013-239.xml',
#  'SOR-2013-24.xml',
#  'SOR-2013-240.xml',
#  'SOR-2013-241.xml',
#  'SOR-2013-242.xml',
#  'SOR-2013-243.xml',
#  'SOR-2013-244.xml',
#  'SOR-2013-249.xml',
#  'SOR-2013-35.xml',
#  'SOR-2013-38.xml',
#  'SOR-2013-39.xml',
#  'SOR-2013-40.xml',
#  'SOR-2013-48.xml',
#  'SOR-2013-50.xml',
#  'SOR-2013-51.xml',
#  'SOR-2013-52.xml',
#  'SOR-2013-58.xml',
#  'SOR-2013-60.xml',
#  'SOR-2013-63.xml',
#  'SOR-2013-69.xml',
#  'SOR-2013-7.xml',
#  'SOR-2013-82.xml',
#  'SOR-2013-87.xml',
#  'SOR-2013-88.xml',
#  'SOR-2014-10.xml',
#  'SOR-2014-104.xml',
#  'SOR-2014-117.xml',
#  'SOR-2014-121.xml',
#  'SOR-2014-128.xml',
#  'SOR-2014-13.xml',
#  'SOR-2014-137.xml',
#  'SOR-2014-16.xml',
#  'SOR-2014-163.xml',
#  'SOR-2014-176.xml',
#  'SOR-2014-177.xml',
#  'SOR-2014-18.xml',
#  'SOR-2014-181.xml',
#  'SOR-2014-189.xml',
#  'SOR-2014-192.xml',
#  'SOR-2014-198.xml',
#  'SOR-2014-200.xml',
#  'SOR-2014-213.xml',
#  'SOR-2014-217.xml',
#  'SOR-2014-218.xml',
#  'SOR-2014-219.xml',
#  'SOR-2014-220.xml',
#  'SOR-2014-221.xml',
#  'SOR-2014-233.xml',
#  'SOR-2014-234.xml',
#  ...]
